# %% [markdown]
# # American Sign Language (ASL) Image Recognition

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Loading in dataset

# %%
import re
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFile  
from sklearn.datasets import load_files
from keras.utils import np_utils
from keras.preprocessing import image                  
from tqdm import tqdm

# For compiling model
from keras.callbacks import ModelCheckpoint   
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, GlobalAveragePooling2D, MaxPooling2D

# For transfer learning
import scipy
import keras.applications.vgg16 as vgg16
import keras.applications.vgg19 as vgg19
import keras.applications.resnet50 as resnet50

# For confusion matrix calculation/visualization
import tensorflow as tf
import seaborn as sn
import pandas as pd

models_dir = 'saved_models'
data_dir = 'data'
bottleneck_feat_dir = 'bottleneck_features'
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-66345e624eb3> in <module>()
#       6 from sklearn.datasets import load_files
#       7 # from keras.utils import np_utils
# ----> 8 from keras.preprocessing import image
#       9 from tqdm import tqdm
#      10
#
# ~/anaconda3/lib/python3.7/site-packages/keras/__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/conv_utils.py in <module>()
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/__init__.py in <module>()
#      87 elif _BACKEND == 'tensorflow':
#      88     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 89     from .tensorflow_backend import *
#      90 else:
#      91     # Try and load external backend.
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in <module>()
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.framework import ops as tf_ops
#       7 from tensorflow.python.training import moving_averages
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ### Dividing data into training, validation, and testing sets
#
# Now that preprocessing the images is completed (see `data_preprocessing.ipynb` notebook), the full dataset will be split into training, validation, and testing sets. The testing set will be all the images from one subject to mirror the "Spelling It Out" paper's method so the benchmark model can be compared. The rest of the images will be randomly split; 80% of images for training, 20% of the images for validation.

# %%
def load_dataset(path, n_categories=24):
    data = load_files(path)
    image_files = np.array(data['filenames'])
    # Hot encode categories to matrix
    image_targets = np_utils.to_categorical(np.array(data['target']), n_categories)
    return image_files, image_targets

def move_data_by_category(container_dir, regex_file_format='.*png'):
    '''Move data into a directory based on category'''
    # Still check if files are images
    file_list = [x for x in os.listdir(container_dir) if re.search(regex_file_format, x)]
    # Get numerical string (note that 1 digits are represented w/ 2 digits) 
    letters = {x.split('_')[0] for x in file_list}
    
    for letter in letters:
        # Only images that match letter
        images_with_letter = [filename for filename in file_list if filename.split('_')[0] == letter]
        # Add images to sub directory
        new_categ_path = os.path.join(container_dir, letter)
        if not os.path.exists(new_categ_path):
            os.makedirs(new_categ_path)
#         print('Created {new_categ_path} dir with {len(images_with_letter)} items')
        for img_filename in images_with_letter:
            path = os.path.join(container_dir, img_filename)
            new_path = os.path.join(new_categ_path, img_filename)            
            os.rename(path, new_path)
    # TODO: Check if any files were skipped (improperly named?)
        

def get_testing_data(data_dir, subject_num='4'):
    '''Get all data/images pertaining to one subject'''
    # Only search in directory for images with that subject
    file_list = [x for x in os.listdir(data_dir) if re.search('\d+_{}_\d*\.png'.format(subject_num), x)]
    
    # Make a new testing data directory if doesn't exist
    testing_dir = os.path.join(data_dir, 'test')
    if not os.path.exists(testing_dir):
        os.makedirs(testing_dir)
        
    # Move images of particular subject into testing directory
    for image_filename in file_list:
        # file is **_n_****.png where n is an integer representing a subject
        _, subject, _ = image_filename.split('_')
        # Move file into testing directory
        path = os.path.join(data_dir, image_filename)
        new_path = os.path.join(testing_dir, image_filename)
        os.rename(path, new_path)
        
    # Move each image file's numerical str representing letters found in testing into own category directory
    move_data_by_category(testing_dir)
    
    return load_dataset(testing_dir)


def get_training_validation_data(data_dir, ratio=0.8):
    '''Randomly split data into training and validation sets'''
    # Only search in directory for images
    file_list = [x for x in os.listdir(data_dir) if re.search('.*png', x)]
    
    # Make a new training & validation data directory if doesn't exist
    train_dir = os.path.join(data_dir, 'train')
    valid_dir = os.path.join(data_dir, 'valid')
    if not os.path.exists(train_dir):
        os.makedirs(train_dir)
    if not os.path.exists(valid_dir):
        os.makedirs(valid_dir)
        
    # Randomly split file list into training and vaidation sets
    np.random.shuffle(file_list)
    split_int = int(ratio * len(file_list))
    train_list = file_list[:split_int]
    valid_list = file_list[split_int:]
    
    # Move images of particular subject into testing directory
    for filenames, new_dir in [(train_list, train_dir), (valid_list, valid_dir)]:
        for image_filename in filenames:
            # Move file into testing directory
            path = os.path.join(data_dir, image_filename)
            new_path = os.path.join(new_dir, image_filename)
            os.rename(path, new_path)

        # Move each image file's numerical str representing letters found in testing into own category directory
        move_data_by_category(new_dir)
    
    return (load_dataset(train_dir), load_dataset(valid_dir))

# %%
# Manually set if the data is RGB
is_rgb = True

test_data, test_targets = get_testing_data(data_dir)
train, valid = get_training_validation_data(data_dir)
# Separated data and its targets
train_data, train_targets = train
valid_data, valid_targets = valid

# %% [markdown]
# ### Display some of the images

# %%
np.random.seed(8675309)
# %matplotlib inline

# Display image previews below
plt.figure(figsize=(20,55))
columns = 8
n = 1

# Randomly choose images to display (with label)
for image_path in np.random.choice(train_data, 24, replace=False):
    img = Image.open(image_path)
    plt.subplot(20, columns, n)
    n+=1
    plt.imshow(img)
    letter = image_path.split('/')[-1][:2]
    letter = chr(int(letter)+65)
    plt.title(letter)

# %% [markdown]
# ### Preparing the model

# %%
# Preprocessing data fro Keras (TensorFlow backend)
def path_to_tensor(img_path):
    # Loads image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224), grayscale=False)
    # Convert PIL.Image.Image type to 3D tensor with shape (224, 224, 1)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 1) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
valid_tensors = paths_to_tensor(valid_data).astype('float32')
test_tensors = paths_to_tensor(test_data).astype('float32')

# %%
# Prepare training data separately since this is usually large
train_tensors = paths_to_tensor(train_data).astype('float32')

# %% [markdown]
# ## Basic CNN model from scratch

# %% [markdown]
# ### Building basic model

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()
#Convo 224, 224, 1
model.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(224, 224, 1)))
#
model.add(MaxPooling2D(pool_size=2))
#
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
#
model.add(MaxPooling2D(pool_size=2))
#
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
#
model.add(MaxPooling2D(pool_size=2))
#
model.add(GlobalAveragePooling2D())
#Dense; 24 for each handshape 
model.add(Dense(24, activation='softmax'))


model.summary()

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Training basic model

# %%
from keras.callbacks import ModelCheckpoint  

epochs = 16

# Create a saved models directory
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

checkpointer = ModelCheckpoint(filepath=f'{models_dir}/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)

# %% [markdown]
# ### Evaluating basic model

# %%
handshape_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(handshape_predictions)==np.argmax(test_targets, axis=1))/len(handshape_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)

# %% [markdown]
# ## Transfer Learning with VGG16

# %% [markdown]
# ### Preparing the model

# %%
# Define image size to use for given model
n_pixels = 80
# Define a model name for records
model_name ='rgbModel_{}px'.format(n_pixels) if is_rgb else 'model_{}px'.format(n_pixels)

# %%
# Preprocessing data fro Keras (TensorFlow backend)
def path_to_tensor(img_path):
    # Loads image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(n_pixels, n_pixels), grayscale=False)
    # Convert PIL.Image.Image type to 3D tensor with shape (n, n, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, n, n, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 
# Pre-process the data for Keras
# Prepare training data separately since this is usually large

print('Preparing to create valid tensors')
valid_tensors = paths_to_tensor(valid_data).astype('float32')
print('valid tensors prepared')

# %%
print('Preparing to create test tensors')
test_tensors = paths_to_tensor(test_data).astype('float32')
print('test tensors prepared')

# %%
print('Preparing to create train tensors')
train_tensors = paths_to_tensor(train_data).astype('float32')
print('train tensors prepared')

# %% [markdown]
# ### Extract Bottleneck Features for Training Set

# %%
# Name & path of bottleneck features
feat_train_name = 'vgg16_{}_features_train'.format(model_name)
feat_train_path = '{}/{}.npz'.format(bottleneck_feat_dir,feat_train_name)

# Load the data
targets = np.squeeze(train_targets)
print('data loaded')

# Load vgg16 model + remove final classification layers
model = vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(n_pixels, n_pixels, 3), classes=24)
print('model loaded')

# Obtain bottleneck features (train)
if os.path.exists(feat_train_path):
    print('bottleneck features detected (train)')
    features = np.load(feat_train_path)['features']
else:
    print('bottleneck features file not detected (train)')
    
    print('calculating now ...')
    # Pre-process the train data
    big_x_train = np.array([scipy.misc.imresize(train_tensors[i], (n_pixels, n_pixels, 3)) 
                            for i in range(0, len(train_tensors))]).astype('float32')
    vgg16_input_train = vgg16.preprocess_input(big_x_train)
    print('train data preprocessed')
    
    # Extract, process, and save bottleneck features
    features = model.predict(vgg16_input_train)
    features = np.squeeze(features)
    np.savez(feat_train_path, features=features)

print('bottleneck features saved (train)')

# %% [markdown]
# ### Extract Bottleneck Features for Validation Set

# %%
# Name & path of bottleneck features
feat_valid_name = 'vgg16_{}_features_valid'.format(model_name)
feat_valid_path = '{}/{}.npz'.format(bottleneck_feat_dir,feat_valid_name)

# Obtain bottleneck features (valid)
if os.path.exists(feat_valid_path):
    print('bottleneck features detected (valid)')
    features_valid = np.load(feat_valid_path)['features_test']
else:
    # Calculating for validation set
    print('bottleneck features file not detected (valid)')
    print('calculating now ...')
    # Pre-process the valid data
    big_x_valid = np.array([scipy.misc.imresize(valid_tensors[i], (n_pixels, n_pixels, 3)) 
                       for i in range(0, len(valid_tensors))]).astype('float32')

    vgg16_input_valid = vgg16.preprocess_input(big_x_valid)
    # Extract, process, and save bottleneck features (valid)
    features_valid = model.predict(vgg16_input_valid)
    features_valid = np.squeeze(features_valid)
    np.savez(feat_valid_path, features_test=features_valid)
print('bottleneck features saved (valid)')

# %% [markdown]
# ### Extract Bottleneck Features for Test Set

# %%
# Name & path of bottleneck features
feat_test_name = 'vgg16_{}_features_test'.format(model_name)
feat_test_path = '{}/{}.npz'.format(bottleneck_feat_dir,feat_test_name)

# Obtain bottleneck features (test)
if os.path.exists(feat_test_path):
    print('bottleneck features detected (test)')
    features_test = np.load(feat_test_path)['features_test']
else:
    # Calculating for test set
    print('bottleneck features file not detected (test)')
    print('calculating now ...')
    # pre-process the test data
    big_x_test = np.array([scipy.misc.imresize(test_tensors[i], (n_pixels, n_pixels, 3)) 
                       for i in range(0, len(test_tensors))]).astype('float32')

    vgg16_input_test = vgg16.preprocess_input(big_x_test)
    # Extract, process, and save bottleneck features (test)
    features_test = model.predict(vgg16_input_test)
    features_test = np.squeeze(features_test)
    np.savez(feat_test_path, features_test=features_test)
print('bottleneck features saved (test)')

# %% [markdown]
# ### Building model

# %%
features.shape
type(features)
features_ = features

# %%
# 3 CNN Layers
model = Sequential()

model.add(Conv2D(filters=256, kernel_size=2, input_shape=features.shape[1:]))
model.add(Dropout(0.4))

model.add(Conv2D(filters=128, kernel_size=1))

model.add(Conv2D(filters=32, kernel_size=1))
model.add(Dropout(0.3))

model.add(GlobalAveragePooling2D())
model.add(Dropout(0.3))

model.add(Dense(24, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
epochs = 50
batchsize = 500
model_weights_path = '{}/vgg16_{}.best_batch{}_epoch{}.hdf5'.format(models_dir,model_name,batchsize,epochs)

checkpointer = ModelCheckpoint(filepath=model_weights_path, 
                               verbose=1, save_best_only=True)

model.fit(features, targets, batch_size=batchsize, epochs=epochs,
          validation_data=(features_valid, valid_targets),
          callbacks=[checkpointer],
          verbose=2, shuffle=True)

# %% [markdown]
# ### Evaluating the model

# %%
# Load the weights that yielded the best validation accuracy
model.load_weights(model_weights_path)

# Evaluate test accuracy
score = model.evaluate(features_test, test_targets, verbose=0)
accuracy = 100*score[1]

# Print test accuracy
print('Test accuracy: %.4f%%' % accuracy)

# %% [markdown]
# ## Transfer Learning with VGG19

# %% [markdown]
# ### Preparing the model

# %%
# Define image size to use for given model
n_pixels = 160
# Define a model name for recorcs
model_name = 'model_{}px'.format(n_pixels)

# %%
# Preprocessing data fro Keras (TensorFlow backend)
def path_to_tensor(img_path):
    # Loads image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(n_pixels, n_pixels), grayscale=False)
    # Convert PIL.Image.Image type to 3D tensor with shape (n, n, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, n, n, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 
# Pre-process the data for Keras
# Prepare training data separately since this is usually large

print('Preparing to create valid tensors')
valid_tensors = paths_to_tensor(valid_data).astype('float32')
print('valid tensors prepared')

# %%
print('Preparing to create test tensors')
test_tensors = paths_to_tensor(test_data).astype('float32')
print('test tensors prepared')

# %%
print('Preparing to create train tensors')
train_tensors = paths_to_tensor(train_data).astype('float32')
print('train tensors prepared')

# %% [markdown]
# ### Extract Bottleneck Features for Training Set

# %%
# Load the data
targets = np.squeeze(train_targets)
print('data loaded')

# Load vgg19 model + remove final classification layers
model = vgg19.VGG19(weights='imagenet', include_top=False, input_shape=(n_pixels, n_pixels, 3), classes=24)
print('model loaded')

# Obtain bottleneck features (train)
if os.path.exists('vgg19_features_train.npz'):
    print('bottleneck features detected (train)')
    features = np.load('vgg19_features_train.npz')['features']
else:
    print('bottleneck features file not detected (train)')
    
    print('calculating now ...')
    # Pre-process the train data
    big_x_train = np.array([scipy.misc.imresize(train_tensors[i], (n_pixels, n_pixels, 3)) 
                            for i in range(0, len(train_tensors))]).astype('float32')
    vgg19_input_train = vgg19.preprocess_input(big_x_train)
    print('train data preprocessed')
    
    # Extract, process, and save bottleneck features
    features = model.predict(vgg19_input_train)
    features = np.squeeze(features)
    np.savez('vgg19_features_train', features=features)

print('bottleneck features saved (train)')

# %% [markdown]
# ### Extract Bottleneck Features for Validation Set

# %%
# Obtain bottleneck features (valid)
if os.path.exists('vgg19_features_valid.npz'):
    print('bottleneck features detected (valid)')
    features_valid = np.load('vgg19_features_valid.npz')['features_test']
else:
    # Calculating for validation set
    print('bottleneck features file not detected (valid)')
    print('calculating now ...')
    # Pre-process the valid data
    big_x_valid = np.array([scipy.misc.imresize(valid_tensors[i], (n_pixels, n_pixels, 3)) 
                       for i in range(0, len(valid_tensors))]).astype('float32')

    vgg19_input_valid = vgg19.preprocess_input(big_x_valid)
    # Extract, process, and save bottleneck features (valid)
    features_valid = model.predict(vgg19_input_valid)
    features_valid = np.squeeze(features_valid)
    np.savez('vgg19_features_valid', features_test=features_valid)
print('bottleneck features saved (valid)')

# %% [markdown]
# ### Extract Bottleneck Features for Test Set

# %%
# Obtain bottleneck features (test)
if os.path.exists('vgg19_features_test.npz'):
    print('bottleneck features detected (test)')
    features_test = np.load('vgg19_features_test.npz')['features_test']
else:
    # Calculating for test set
    print('bottleneck features file not detected (test)')
    print('calculating now ...')
    # pre-process the test data
    big_x_test = np.array([scipy.misc.imresize(test_tensors[i], (n_pixels, n_pixels, 3)) 
                       for i in range(0, len(test_tensors))]).astype('float32')

    vgg19_input_test = vgg19.preprocess_input(big_x_test)
    # Extract, process, and save bottleneck features (test)
    features_test = model.predict(vgg19_input_test)
    features_test = np.squeeze(features_test)
    np.savez('vgg19_features_test', features_test=features_test)
print('bottleneck features saved (test)')

# %% [markdown]
# ### Building model

# %%
# Shallow NN
from keras.callbacks import ModelCheckpoint   
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, GlobalAveragePooling2D

model = Sequential()
model.add(Conv2D(filters=256, kernel_size=2, input_shape=features.shape[1:]))
model.add(Dropout(0.4))
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.3))
model.add(Dense(24, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
epochs = 256
batchsize = 512
model_weights_path = f'{models_dir}/vgg19_new_{model_name}.best_batch{batchsize}_epoch{epochs}.hdf5'

checkpointer = ModelCheckpoint(filepath=model_weights_path, 
                               verbose=1, save_best_only=True)

model.fit(features, targets, batch_size=batchsize, epochs=epochs,
          validation_data=(features_valid, valid_targets),
          callbacks=[checkpointer],
          verbose=2, shuffle=True)

# %% [markdown]
# ### Evaluating the model

# %%
# Load the weights that yielded the best validation accuracy
model.load_weights(model_weights_path)

# Evaluate test accuracy
score = model.evaluate(features_test, test_targets, verbose=0)
accuracy = 100*score[1]

# Print test accuracy
print('Test accuracy: %.4f%%' % accuracy)

# %% [markdown]
# ## Transfer Learning with ResNet50

# %% [markdown]
# ### Preparing the model

# %%
# Define image size to use for given model
n_pixels = 197
# Define a model name for records
model_name ='rgbModel_{}px'.format(n_pixels) if is_rgb else 'model_{}px'.format(n_pixels)

# %%
# Preprocessing data fro Keras (TensorFlow backend)
def path_to_tensor(img_path):
    # Loads image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(n_pixels, n_pixels), grayscale=False)
    # Convert PIL.Image.Image type to 3D tensor with shape (n, n, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, n, n, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %%
ImageFile.LOAD_TRUNCATED_IMAGES = True                 
# Pre-process the data for Keras
# Prepare training data separately since this is usually large

print('Preparing to create valid tensors')
valid_tensors = paths_to_tensor(valid_data).astype('float32')
print('valid tensors prepared')
# Out:
#   1%|          | 69/10599 [00:00<00:15, 686.63it/s]
# Preparing to create valid tensors
# 100%|██████████| 10599/10599 [00:16<00:00, 658.26it/s]
# valid tensors prepared

# %%
print('Preparing to create test tensors')
test_tensors = paths_to_tensor(test_data).astype('float32')
print('test tensors prepared')
# Out:
#   0%|          | 58/12782 [00:00<00:22, 577.28it/s]
# Preparing to create test tensors
# 100%|██████████| 12782/12782 [00:21<00:00, 594.40it/s]
# test tensors prepared

# %%
print('Preparing to create train tensors')
train_tensors = paths_to_tensor(train_data).astype('float32')
print('train tensors prepared')
# Out:
# Preparing to create train tensors
# train tensors prepared

# %% [markdown]
# ### Extract Bottleneck Features for Training Set

# %%
# Name & path of bottleneck features
feat_train_name = 'resnet50_{}_features_train'.format(model_name)
feat_train_path = '{}/{}.npz'.format(bottleneck_feat_dir,feat_train_name)

# Load the data
targets = np.squeeze(train_targets)
print('data loaded')

# Load resnet50 model + remove final classification layers
model = resnet50.ResNet50(weights='imagenet', include_top=False, input_shape=(n_pixels, n_pixels, 3), classes=24)
print('model loaded')

# Obtain bottleneck features (train)
if os.path.exists(feat_train_path):
    print('bottleneck features detected (train)')
    features = np.load(feat_train_path)['features']
else:
    print('bottleneck features file not detected (train)')
    
    print('calculating now ...')
    # Pre-process the train data
    big_x_train = np.array([scipy.misc.imresize(train_tensors[i], (n_pixels, n_pixels, 3)) 
                            for i in range(0, len(train_tensors))]).astype('float32')
    resnet50_input_train = resnet50.preprocess_input(big_x_train)
    print('train data preprocessed')
    
    # Extract, process, and save bottleneck features
    features = model.predict(resnet50_input_train)
#     features = np.squeeze(features)
    np.savez(feat_train_path, features=features)

print('bottleneck features saved (train)')
# Out:
# data loaded
# model loaded
# bottleneck features detected (train)
# bottleneck features saved (train)

# %% [markdown]
# ### Extract Bottleneck Features for Validation Set

# %%
# Name & path of bottleneck features
feat_valid_name = 'resnet50_{}_features_valid'.format(model_name)
feat_valid_path = '{}/{}.npz'.format(bottleneck_feat_dir,feat_valid_name)

# Obtain bottleneck features (valid)
if os.path.exists(feat_valid_path):
    print('bottleneck features detected (valid)')
    features_valid = np.load(feat_valid_path)['features_test']
else:
    # Calculating for validation set
    print('bottleneck features file not detected (valid)')
    print('calculating now ...')
    # Pre-process the valid data
    big_x_valid = np.array([scipy.misc.imresize(valid_tensors[i], (n_pixels, n_pixels, 3)) 
                       for i in range(0, len(valid_tensors))]).astype('float32')

    resnet50_input_valid = resnet50.preprocess_input(big_x_valid)
    # Extract, process, and save bottleneck features (valid)
    features_valid = model.predict(resnet50_input_valid)
#     features_valid = np.squeeze(features_valid)
    np.savez(feat_valid_path, features_test=features_valid)
print('bottleneck features saved (valid)')
# Out:
# bottleneck features detected (valid)
# bottleneck features saved (valid)

# %% [markdown]
# ### Extract Bottleneck Features for Test Set

# %%
# Name & path of bottleneck features
feat_test_name = 'resnet50_{}_features_test'.format(model_name)
feat_test_path = '{}/{}.npz'.format(bottleneck_feat_dir,feat_test_name)

# Obtain bottleneck features (test)
if os.path.exists(feat_test_path):
    print('bottleneck features detected (test)')
    features_test = np.load(feat_test_path)['features_test']
else:
    # Calculating for test set
    print('bottleneck features file not detected (test)')
    print('calculating now ...')
    # pre-process the test data
    big_x_test = np.array([scipy.misc.imresize(test_tensors[i], (n_pixels, n_pixels, 3)) 
                       for i in range(0, len(test_tensors))]).astype('float32')

    resnet50_input_test = resnet50.preprocess_input(big_x_test)
    # Extract, process, and save bottleneck features (test)
    features_test = model.predict(resnet50_input_test)
#     features_test = np.squeeze(features_test)
    np.savez(feat_test_path, features_test=features_test)
print('bottleneck features saved (test)')
# Out:
# bottleneck features detected (test)
# bottleneck features saved (test)

# %% [markdown]
# ### Building model

# %%
# 3 CNN Layers
from keras.layers import MaxPooling2D

model = Sequential()

model.add(Conv2D(filters=512, kernel_size=1, input_shape=features.shape[1:]))
model.add(Dropout(0.2))

model.add(Conv2D(filters=256, kernel_size=1))
model.add(MaxPooling2D(pool_size=1))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=1))
model.add(MaxPooling2D(pool_size=1))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=1))

model.add(GlobalAveragePooling2D())
model.add(Dropout(0.3))

model.add(Dense(24, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 1, 1, 512)         1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 1, 256)         131328
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 1, 128)         32896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 128)         16512
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 128)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 24)                3096
# =================================================================
# Total params: 1,232,920
# Trainable params: 1,232,920
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 1536
batchsize = 8192
model_details = 'resnet50_{}_batch{}_epoch{}'.format(model_name,batchsize,epochs)
model_weights_path = '{}/{}.hdf5'.format(models_dir,model_details)

checkpointer = ModelCheckpoint(filepath=model_weights_path, 
                               verbose=1, save_best_only=True)

model.fit(features, targets, batch_size=batchsize, epochs=epochs,
          validation_data=(features_valid, valid_targets),
          callbacks=[checkpointer],
          verbose=2, shuffle=True)
# Out:
# Train on 42393 samples, validate on 10599 samples
# Epoch 1/1536
# Epoch 00000: val_loss improved from inf to 0.05668, saving model to saved_models/resnet50_rgbModel_197px_batch8192_epoch1536.hdf5
# 0s - loss: 0.0279 - acc: 0.9910 - val_loss: 0.0567 - val_acc: 0.9825
# Epoch 2/1536
# Epoch 00001: val_loss did not improve
# 0s - loss: 0.0281 - acc: 0.9908 - val_loss: 0.0627 - val_acc: 0.9791
# Epoch 3/1536
# Epoch 00002: val_loss did not improve
# 0s - loss: 0.0797 - acc: 0.9749 - val_loss: 0.5369 - val_acc: 0.8987
# Epoch 4/1536
# Epoch 00003: val_loss did not improve
# 0s - loss: 0.6408 - acc: 0.8752 - val_loss: 0.5027 - val_acc: 0.8886
# Epoch 5/1536
# Epoch 00004: val_loss did not improve
# 0s - loss: 0.2616 - acc: 0.9353 - val_loss: 0.0622 - val_acc: 0.9792
# Epoch 6/1536
# Epoch 00005: val_loss did not improve
# 0s - loss: 0.0330 - acc: 0.9889 - val_loss: 0.0580 - val_acc: 0.9808
# Epoch 7/1536
# Epoch 00006: val_loss did not improve
# 0s - loss: 0.0278 - acc: 0.9913 - val_loss: 0.0599 - val_acc: 0.9802
# Epoch 8/1536
# Epoch 00007: val_loss did not improve
# 0s - loss: 0.0301 - acc: 0.9899 - val_loss: 0.0575 - val_acc: 0.9811
# Epoch 9/1536
# Epoch 00008: val_loss did not improve
# 0s - loss: 0.0317 - acc: 0.9888 - val_loss: 0.0835 - val_acc: 0.9725
# Epoch 10/1536
# Epoch 00009: val_loss did not improve
# 0s - loss: 0.8056 - acc: 0.8745 - val_loss: 0.9524 - val_acc: 0.8303
# Epoch 11/1536
# Epoch 00010: val_loss did not improve
# 0s - loss: 0.9819 - acc: 0.8248 - val_loss: 0.0780 - val_acc: 0.9754
# Epoch 12/1536
# Epoch 00011: val_loss did not improve
# 0s - loss: 0.0460 - acc: 0.9837 - val_loss: 0.0666 - val_acc: 0.9795
# Epoch 13/1536
# Epoch 00012: val_loss did not improve
# 0s - loss: 0.0345 - acc: 0.9879 - val_loss: 0.0655 - val_acc: 0.9794
# Epoch 14/1536
# Epoch 00013: val_loss did not improve
# 0s - loss: 0.0338 - acc: 0.9884 - val_loss: 0.0616 - val_acc: 0.9820
# Epoch 15/1536
# Epoch 00014: val_loss did not improve
# 0s - loss: 0.0315 - acc: 0.9892 - val_loss: 0.0647 - val_acc: 0.9808
# Epoch 16/1536
# Epoch 00015: val_loss did not improve
# 0s - loss: 0.0297 - acc: 0.9902 - val_loss: 0.0866 - val_acc: 0.9744
# Epoch 17/1536
# Epoch 00016: val_loss did not improve
# 0s - loss: 0.2558 - acc: 0.9335 - val_loss: 0.7897 - val_acc: 0.8353
# Epoch 18/1536
# Epoch 00017: val_loss did not improve
# 0s - loss: 0.7957 - acc: 0.8436 - val_loss: 0.1211 - val_acc: 0.9634
# Epoch 19/1536
# Epoch 00018: val_loss did not improve
# 0s - loss: 0.0464 - acc: 0.9845 - val_loss: 0.0648 - val_acc: 0.9800
# Epoch 20/1536
# Epoch 00019: val_loss did not improve
# 0s - loss: 0.0327 - acc: 0.9885 - val_loss: 0.0602 - val_acc: 0.9801
# Epoch 21/1536
# Epoch 00020: val_loss did not improve
# 0s - loss: 0.0330 - acc: 0.9886 - val_loss: 0.0641 - val_acc: 0.9785
# Epoch 22/1536
# Epoch 00021: val_loss did not improve
# 0s - loss: 0.0330 - acc: 0.9883 - val_loss: 0.0731 - val_acc: 0.9762
# Epoch 23/1536
# Epoch 00022: val_loss did not improve
# 0s - loss: 0.3287 - acc: 0.9330 - val_loss: 1.4661 - val_acc: 0.7657
# Epoch 24/1536
# Epoch 00023: val_loss did not improve
# 0s - loss: 0.9616 - acc: 0.8355 - val_loss: 0.0753 - val_acc: 0.9758
# Epoch 25/1536
# Epoch 00024: val_loss did not improve
# 0s - loss: 0.0428 - acc: 0.9856 - val_loss: 0.0655 - val_acc: 0.9791
# Epoch 26/1536
# Epoch 00025: val_loss did not improve
# 0s - loss: 0.0363 - acc: 0.9874 - val_loss: 0.0618 - val_acc: 0.9811
# Epoch 27/1536
# Epoch 00026: val_loss did not improve
# 0s - loss: 0.0341 - acc: 0.9891 - val_loss: 0.0641 - val_acc: 0.9800
# Epoch 28/1536
# Epoch 00027: val_loss did not improve
# 0s - loss: 0.0333 - acc: 0.9887 - val_loss: 0.0924 - val_acc: 0.9716
# Epoch 29/1536
# Epoch 00028: val_loss did not improve
# 0s - loss: 0.6248 - acc: 0.8928 - val_loss: 2.5458 - val_acc: 0.7112
# Epoch 30/1536
# Epoch 00029: val_loss did not improve
# 0s - loss: 0.8544 - acc: 0.8747 - val_loss: 0.0738 - val_acc: 0.9759
# Epoch 31/1536
# Epoch 00030: val_loss did not improve
# 0s - loss: 0.0409 - acc: 0.9859 - val_loss: 0.0684 - val_acc: 0.9780
# Epoch 32/1536
# Epoch 00031: val_loss did not improve
# 0s - loss: 0.0371 - acc: 0.9879 - val_loss: 0.0685 - val_acc: 0.9770
# Epoch 33/1536
# Epoch 00032: val_loss did not improve
# 0s - loss: 0.0334 - acc: 0.9891 - val_loss: 0.0652 - val_acc: 0.9773
# Epoch 34/1536
# Epoch 00033: val_loss did not improve
# 0s - loss: 0.0324 - acc: 0.9890 - val_loss: 0.1113 - val_acc: 0.9654
# Epoch 35/1536
# Epoch 00034: val_loss did not improve
# 0s - loss: 0.3243 - acc: 0.9291 - val_loss: 0.3936 - val_acc: 0.9030
# Epoch 36/1536
# Epoch 00035: val_loss did not improve
# 0s - loss: 0.5218 - acc: 0.8843 - val_loss: 0.1351 - val_acc: 0.9608
# Epoch 37/1536
# Epoch 00036: val_loss did not improve
# 0s - loss: 0.0469 - acc: 0.9845 - val_loss: 0.0612 - val_acc: 0.9811
# Epoch 38/1536
# Epoch 00037: val_loss did not improve
# 0s - loss: 0.0306 - acc: 0.9901 - val_loss: 0.0591 - val_acc: 0.9813
# Epoch 39/1536
# Epoch 00038: val_loss did not improve
# 0s - loss: 0.0281 - acc: 0.9907 - val_loss: 0.0596 - val_acc: 0.9807
# Epoch 40/1536
# Epoch 00039: val_loss did not improve
# 0s - loss: 0.0329 - acc: 0.9884 - val_loss: 0.5975 - val_acc: 0.9202
# Epoch 41/1536
# Epoch 00040: val_loss did not improve
# 0s - loss: 0.8515 - acc: 0.8610 - val_loss: 0.6463 - val_acc: 0.8554
# Epoch 42/1536
# Epoch 00041: val_loss did not improve
# 0s - loss: 0.2738 - acc: 0.9390 - val_loss: 0.0615 - val_acc: 0.9798
# Epoch 43/1536
# Epoch 00042: val_loss did not improve
# 0s - loss: 0.0339 - acc: 0.9880 - val_loss: 0.0597 - val_acc: 0.9803
# Epoch 44/1536
# Epoch 00043: val_loss did not improve
# 0s - loss: 0.0296 - acc: 0.9902 - val_loss: 0.0632 - val_acc: 0.9796
# Epoch 45/1536
# Epoch 00044: val_loss did not improve
# 0s - loss: 0.0308 - acc: 0.9895 - val_loss: 0.0766 - val_acc: 0.9765
# Epoch 46/1536
# Epoch 00045: val_loss did not improve
# 0s - loss: 0.1605 - acc: 0.9558 - val_loss: 0.4152 - val_acc: 0.9054
# Epoch 47/1536
# Epoch 00046: val_loss did not improve
# 0s - loss: 0.6363 - acc: 0.8718 - val_loss: 0.2123 - val_acc: 0.9412
# Epoch 48/1536
# Epoch 00047: val_loss did not improve
# 0s - loss: 0.0884 - acc: 0.9725 - val_loss: 0.0618 - val_acc: 0.9807
# Epoch 49/1536
# Epoch 00048: val_loss did not improve
# 0s - loss: 0.0305 - acc: 0.9905 - val_loss: 0.0596 - val_acc: 0.9809
# Epoch 50/1536
# Epoch 00049: val_loss did not improve
# 0s - loss: 0.0292 - acc: 0.9902 - val_loss: 0.0589 - val_acc: 0.9812
# Epoch 51/1536
# Epoch 00050: val_loss did not improve
# 0s - loss: 0.0282 - acc: 0.9903 - val_loss: 0.0998 - val_acc: 0.9699
# Epoch 52/1536
# Epoch 00051: val_loss did not improve
# 0s - loss: 0.4077 - acc: 0.9164 - val_loss: 1.7263 - val_acc: 0.7740
# Epoch 53/1536
# Epoch 00052: val_loss did not improve
# 0s - loss: 2.0529 - acc: 0.7467 - val_loss: 0.0819 - val_acc: 0.9744
# Epoch 54/1536
# Epoch 00053: val_loss did not improve
# 0s - loss: 0.0519 - acc: 0.9826 - val_loss: 0.0705 - val_acc: 0.9773
# Epoch 55/1536
# Epoch 00054: val_loss did not improve
# 0s - loss: 0.0426 - acc: 0.9862 - val_loss: 0.0670 - val_acc: 0.9787
# Epoch 56/1536
# Epoch 00055: val_loss did not improve
# 0s - loss: 0.0384 - acc: 0.9869 - val_loss: 0.0655 - val_acc: 0.9792
# Epoch 57/1536
# Epoch 00056: val_loss did not improve
# 0s - loss: 0.0343 - acc: 0.9883 - val_loss: 0.0712 - val_acc: 0.9782
# Epoch 58/1536
# Epoch 00057: val_loss did not improve
# 0s - loss: 0.0442 - acc: 0.9846 - val_loss: 0.1012 - val_acc: 0.9694
# Epoch 59/1536
# Epoch 00058: val_loss did not improve
# 0s - loss: 0.0845 - acc: 0.9716 - val_loss: 0.1039 - val_acc: 0.9683
# Epoch 60/1536
# Epoch 00059: val_loss did not improve
# 0s - loss: 0.5012 - acc: 0.8947 - val_loss: 1.9712 - val_acc: 0.6962
# Epoch 61/1536
# Epoch 00060: val_loss did not improve
# 0s - loss: 1.3975 - acc: 0.8061 - val_loss: 0.0815 - val_acc: 0.9756
# Epoch 62/1536
# Epoch 00061: val_loss did not improve
# 0s - loss: 0.0441 - acc: 0.9850 - val_loss: 0.0701 - val_acc: 0.9783
# Epoch 63/1536
# Epoch 00062: val_loss did not improve
# 0s - loss: 0.0365 - acc: 0.9882 - val_loss: 0.0699 - val_acc: 0.9776
# Epoch 64/1536
# Epoch 00063: val_loss did not improve
# 0s - loss: 0.0337 - acc: 0.9884 - val_loss: 0.0678 - val_acc: 0.9787
# Epoch 65/1536
# Epoch 00064: val_loss did not improve
# 0s - loss: 0.0314 - acc: 0.9894 - val_loss: 0.0667 - val_acc: 0.9784
# Epoch 66/1536
# Epoch 00065: val_loss did not improve
# 0s - loss: 0.0314 - acc: 0.9895 - val_loss: 0.1144 - val_acc: 0.9650
# Epoch 67/1536
# Epoch 00066: val_loss did not improve
# 0s - loss: 0.4606 - acc: 0.9086 - val_loss: 1.5471 - val_acc: 0.7663
# Epoch 68/1536
# Epoch 00067: val_loss did not improve
# 0s - loss: 0.9674 - acc: 0.8531 - val_loss: 0.0711 - val_acc: 0.9772
# Epoch 69/1536
# Epoch 00068: val_loss did not improve
# 0s - loss: 0.0397 - acc: 0.9863 - val_loss: 0.0665 - val_acc: 0.9784
# Epoch 70/1536
# Epoch 00069: val_loss did not improve
# 0s - loss: 0.0344 - acc: 0.9881 - val_loss: 0.0697 - val_acc: 0.9774
# Epoch 71/1536
# Epoch 00070: val_loss did not improve
# 0s - loss: 0.0307 - acc: 0.9896 - val_loss: 0.0638 - val_acc: 0.9784
# Epoch 72/1536
# Epoch 00071: val_loss did not improve
# 0s - loss: 0.0362 - acc: 0.9873 - val_loss: 0.2152 - val_acc: 0.9420
# Epoch 73/1536
# Epoch 00072: val_loss did not improve
# 0s - loss: 0.1965 - acc: 0.9412 - val_loss: 0.0788 - val_acc: 0.9747
# Epoch 74/1536
# Epoch 00073: val_loss did not improve
# 0s - loss: 0.0325 - acc: 0.9886 - val_loss: 0.0643 - val_acc: 0.9797
# Epoch 75/1536
# Epoch 00074: val_loss did not improve
# 0s - loss: 0.0266 - acc: 0.9910 - val_loss: 0.1040 - val_acc: 0.9671
# Epoch 76/1536
# Epoch 00075: val_loss did not improve
# 0s - loss: 0.9024 - acc: 0.8718 - val_loss: 2.6590 - val_acc: 0.7039
# Epoch 77/1536
# Epoch 00076: val_loss did not improve
# 0s - loss: 1.4747 - acc: 0.8136 - val_loss: 0.0767 - val_acc: 0.9768
# Epoch 78/1536
# Epoch 00077: val_loss did not improve
# 0s - loss: 0.0425 - acc: 0.9852 - val_loss: 0.0689 - val_acc: 0.9785
# Epoch 79/1536
# Epoch 00078: val_loss did not improve
# 0s - loss: 0.0377 - acc: 0.9875 - val_loss: 0.0670 - val_acc: 0.9792
# Epoch 80/1536
# Epoch 00079: val_loss did not improve
# 0s - loss: 0.0347 - acc: 0.9881 - val_loss: 0.0652 - val_acc: 0.9800
# Epoch 81/1536
# Epoch 00080: val_loss did not improve
# 0s - loss: 0.0289 - acc: 0.9902 - val_loss: 0.0665 - val_acc: 0.9802
# Epoch 82/1536
# Epoch 00081: val_loss did not improve
# 0s - loss: 0.0297 - acc: 0.9893 - val_loss: 0.0759 - val_acc: 0.9772
# Epoch 83/1536
# Epoch 00082: val_loss did not improve
# 0s - loss: 0.0509 - acc: 0.9821 - val_loss: 0.5862 - val_acc: 0.8888
# Epoch 84/1536
# Epoch 00083: val_loss did not improve
# 0s - loss: 0.9433 - acc: 0.8454 - val_loss: 0.8598 - val_acc: 0.8447
# Epoch 85/1536
# Epoch 00084: val_loss did not improve
# 0s - loss: 0.2969 - acc: 0.9351 - val_loss: 0.0704 - val_acc: 0.9801
# Epoch 86/1536
# Epoch 00085: val_loss did not improve
# 0s - loss: 0.0335 - acc: 0.9889 - val_loss: 0.0679 - val_acc: 0.9807
# Epoch 87/1536
# Epoch 00086: val_loss did not improve
# 0s - loss: 0.0304 - acc: 0.9894 - val_loss: 0.0661 - val_acc: 0.9807
# Epoch 88/1536
# Epoch 00087: val_loss did not improve
# 0s - loss: 0.0272 - acc: 0.9908 - val_loss: 0.0624 - val_acc: 0.9817
# Epoch 89/1536
# Epoch 00088: val_loss did not improve
# 0s - loss: 0.0281 - acc: 0.9906 - val_loss: 0.0850 - val_acc: 0.9744
# Epoch 90/1536
# Epoch 00089: val_loss did not improve
# 0s - loss: 0.3674 - acc: 0.9351 - val_loss: 1.3607 - val_acc: 0.7958
# Epoch 91/1536
# Epoch 00090: val_loss did not improve
# 0s - loss: 1.2512 - acc: 0.8049 - val_loss: 0.0832 - val_acc: 0.9758
# Epoch 92/1536
# Epoch 00091: val_loss did not improve
# 0s - loss: 0.0385 - acc: 0.9863 - val_loss: 0.0691 - val_acc: 0.9778
# Epoch 93/1536
# Epoch 00092: val_loss did not improve
# 0s - loss: 0.0315 - acc: 0.9891 - val_loss: 0.0684 - val_acc: 0.9787
# Epoch 94/1536
# Epoch 00093: val_loss did not improve
# 0s - loss: 0.0290 - acc: 0.9898 - val_loss: 0.0662 - val_acc: 0.9786
# Epoch 95/1536
# Epoch 00094: val_loss did not improve
# 0s - loss: 0.0279 - acc: 0.9901 - val_loss: 0.0636 - val_acc: 0.9800
# Epoch 96/1536
# Epoch 00095: val_loss did not improve
# 0s - loss: 0.0267 - acc: 0.9904 - val_loss: 0.0713 - val_acc: 0.9786
# Epoch 97/1536
# Epoch 00096: val_loss did not improve
# 0s - loss: 0.0852 - acc: 0.9736 - val_loss: 0.8308 - val_acc: 0.8556
# Epoch 98/1536
# Epoch 00097: val_loss did not improve
# 0s - loss: 1.0873 - acc: 0.8289 - val_loss: 0.4355 - val_acc: 0.9046
# Epoch 99/1536
# Epoch 00098: val_loss did not improve
# 0s - loss: 0.1300 - acc: 0.9671 - val_loss: 0.0703 - val_acc: 0.9784
# Epoch 100/1536
# Epoch 00099: val_loss did not improve
# 0s - loss: 0.0331 - acc: 0.9891 - val_loss: 0.0723 - val_acc: 0.9774
# Epoch 101/1536
# Epoch 00100: val_loss did not improve
# 0s - loss: 0.0301 - acc: 0.9896 - val_loss: 0.0641 - val_acc: 0.9798
# Epoch 102/1536
# Epoch 00101: val_loss did not improve
# 0s - loss: 0.0288 - acc: 0.9900 - val_loss: 0.0621 - val_acc: 0.9801
# Epoch 103/1536
# Epoch 00102: val_loss did not improve
# 0s - loss: 0.0451 - acc: 0.9843 - val_loss: 0.5636 - val_acc: 0.8921
# Epoch 104/1536
# Epoch 00103: val_loss did not improve
# 0s - loss: 0.9950 - acc: 0.8332 - val_loss: 0.1510 - val_acc: 0.9578
# Epoch 105/1536
# Epoch 00104: val_loss did not improve
# 0s - loss: 0.0561 - acc: 0.9814 - val_loss: 0.0669 - val_acc: 0.9796
# Epoch 106/1536
# Epoch 00105: val_loss did not improve
# 0s - loss: 0.0300 - acc: 0.9897 - val_loss: 0.0613 - val_acc: 0.9812
# Epoch 107/1536
# Epoch 00106: val_loss did not improve
# 0s - loss: 0.0299 - acc: 0.9897 - val_loss: 0.0720 - val_acc: 0.9781
# Epoch 108/1536
# Epoch 00107: val_loss did not improve
# 0s - loss: 0.0475 - acc: 0.9834 - val_loss: 0.2569 - val_acc: 0.9267
# Epoch 109/1536
# Epoch 00108: val_loss did not improve
# 0s - loss: 0.3048 - acc: 0.9181 - val_loss: 1.1424 - val_acc: 0.8442
# Epoch 110/1536
# Epoch 00109: val_loss did not improve
# 0s - loss: 1.1556 - acc: 0.8241 - val_loss: 0.0891 - val_acc: 0.9729
# Epoch 111/1536
# Epoch 00110: val_loss did not improve
# 0s - loss: 0.0406 - acc: 0.9858 - val_loss: 0.0735 - val_acc: 0.9772
# Epoch 112/1536
# Epoch 00111: val_loss did not improve
# 0s - loss: 0.0329 - acc: 0.9888 - val_loss: 0.0642 - val_acc: 0.9800
# Epoch 113/1536
# Epoch 00112: val_loss did not improve
# 0s - loss: 0.0292 - acc: 0.9899 - val_loss: 0.0676 - val_acc: 0.9799
# Epoch 114/1536
# Epoch 00113: val_loss did not improve
# 0s - loss: 0.0285 - acc: 0.9902 - val_loss: 0.0648 - val_acc: 0.9801
# Epoch 115/1536
# Epoch 00114: val_loss did not improve
# 0s - loss: 0.0324 - acc: 0.9889 - val_loss: 0.1084 - val_acc: 0.9647
# Epoch 116/1536
# Epoch 00115: val_loss did not improve
# 0s - loss: 0.4112 - acc: 0.9171 - val_loss: 0.3774 - val_acc: 0.9060
# Epoch 117/1536
# Epoch 00116: val_loss did not improve
# 0s - loss: 0.2516 - acc: 0.9311 - val_loss: 0.0637 - val_acc: 0.9793
# Epoch 118/1536
# Epoch 00117: val_loss did not improve
# 0s - loss: 0.0278 - acc: 0.9903 - val_loss: 0.0583 - val_acc: 0.9818
# Epoch 119/1536
# Epoch 00118: val_loss did not improve
# 0s - loss: 0.0255 - acc: 0.9910 - val_loss: 0.0570 - val_acc: 0.9820
# Epoch 120/1536
# Epoch 00119: val_loss did not improve
# 0s - loss: 0.0304 - acc: 0.9899 - val_loss: 0.3539 - val_acc: 0.9255
# Epoch 121/1536
# Epoch 00120: val_loss did not improve
# 0s - loss: 1.2422 - acc: 0.8217 - val_loss: 1.6152 - val_acc: 0.7574
# Epoch 122/1536
# Epoch 00121: val_loss did not improve
# 0s - loss: 0.7545 - acc: 0.8767 - val_loss: 0.0778 - val_acc: 0.9772
# Epoch 123/1536
# Epoch 00122: val_loss did not improve
# 0s - loss: 0.0397 - acc: 0.9862 - val_loss: 0.0703 - val_acc: 0.9792
# Epoch 124/1536
# Epoch 00123: val_loss did not improve
# 0s - loss: 0.0329 - acc: 0.9885 - val_loss: 0.0680 - val_acc: 0.9801
# Epoch 125/1536
# Epoch 00124: val_loss did not improve
# 0s - loss: 0.0302 - acc: 0.9899 - val_loss: 0.0667 - val_acc: 0.9798
# Epoch 126/1536
# Epoch 00125: val_loss did not improve
# 0s - loss: 0.0291 - acc: 0.9902 - val_loss: 0.0655 - val_acc: 0.9799
# Epoch 127/1536
# Epoch 00126: val_loss did not improve
# 0s - loss: 0.0261 - acc: 0.9915 - val_loss: 0.0820 - val_acc: 0.9755
# Epoch 128/1536
# Epoch 00127: val_loss did not improve
# 0s - loss: 0.1451 - acc: 0.9611 - val_loss: 0.4728 - val_acc: 0.8904
# Epoch 129/1536
# Epoch 00128: val_loss did not improve
# 0s - loss: 1.0517 - acc: 0.8320 - val_loss: 0.6268 - val_acc: 0.8653
# Epoch 130/1536
# Epoch 00129: val_loss did not improve
# 0s - loss: 0.2555 - acc: 0.9423 - val_loss: 0.0684 - val_acc: 0.9793
# Epoch 131/1536
# Epoch 00130: val_loss did not improve
# 0s - loss: 0.0307 - acc: 0.9896 - val_loss: 0.0654 - val_acc: 0.9794
# Epoch 132/1536
# Epoch 00131: val_loss did not improve
# 0s - loss: 0.0274 - acc: 0.9908 - val_loss: 0.0601 - val_acc: 0.9808
# Epoch 133/1536
# Epoch 00132: val_loss did not improve
# 0s - loss: 0.0253 - acc: 0.9911 - val_loss: 0.0609 - val_acc: 0.9802
# Epoch 134/1536
# Epoch 00133: val_loss did not improve
# 0s - loss: 0.0322 - acc: 0.9891 - val_loss: 0.1398 - val_acc: 0.9596
# Epoch 135/1536
# Epoch 00134: val_loss did not improve
# 0s - loss: 0.4387 - acc: 0.9048 - val_loss: 0.5116 - val_acc: 0.9008
# Epoch 136/1536
# Epoch 00135: val_loss did not improve
# 0s - loss: 0.1914 - acc: 0.9507 - val_loss: 0.0631 - val_acc: 0.9812
# Epoch 137/1536
# Epoch 00136: val_loss did not improve
# 0s - loss: 0.0254 - acc: 0.9914 - val_loss: 0.0658 - val_acc: 0.9802
# Epoch 138/1536
# Epoch 00137: val_loss did not improve
# 0s - loss: 0.0269 - acc: 0.9912 - val_loss: 0.0734 - val_acc: 0.9776
# Epoch 139/1536
# Epoch 00138: val_loss did not improve
# 0s - loss: 0.0325 - acc: 0.9890 - val_loss: 0.0725 - val_acc: 0.9779
# Epoch 140/1536
# Epoch 00139: val_loss did not improve
# 0s - loss: 0.1132 - acc: 0.9682 - val_loss: 0.7311 - val_acc: 0.8562
# Epoch 141/1536
# Epoch 00140: val_loss did not improve
# 0s - loss: 1.3693 - acc: 0.7893 - val_loss: 0.1095 - val_acc: 0.9679
# Epoch 142/1536
# Epoch 00141: val_loss did not improve
# 0s - loss: 0.0486 - acc: 0.9841 - val_loss: 0.0652 - val_acc: 0.9797
# Epoch 143/1536
# Epoch 00142: val_loss did not improve
# 0s - loss: 0.0320 - acc: 0.9890 - val_loss: 0.0631 - val_acc: 0.9808
# Epoch 144/1536
# Epoch 00143: val_loss did not improve
# 0s - loss: 0.0288 - acc: 0.9909 - val_loss: 0.0616 - val_acc: 0.9802
# Epoch 145/1536
# Epoch 00144: val_loss did not improve
# 0s - loss: 0.0257 - acc: 0.9915 - val_loss: 0.0615 - val_acc: 0.9812
# Epoch 146/1536
# Epoch 00145: val_loss did not improve
# 0s - loss: 0.0255 - acc: 0.9918 - val_loss: 0.0683 - val_acc: 0.9795
# Epoch 147/1536
# Epoch 00146: val_loss did not improve
# 0s - loss: 0.1401 - acc: 0.9625 - val_loss: 0.5607 - val_acc: 0.8756
# Epoch 148/1536
# Epoch 00147: val_loss did not improve
# 0s - loss: 1.1141 - acc: 0.8151 - val_loss: 0.7841 - val_acc: 0.8493
# Epoch 149/1536
# Epoch 00148: val_loss did not improve
# 0s - loss: 0.2751 - acc: 0.9382 - val_loss: 0.0644 - val_acc: 0.9795
# Epoch 150/1536
# Epoch 00149: val_loss did not improve
# 0s - loss: 0.0289 - acc: 0.9900 - val_loss: 0.0602 - val_acc: 0.9811
# Epoch 151/1536
# Epoch 00150: val_loss did not improve
# 0s - loss: 0.0279 - acc: 0.9903 - val_loss: 0.0586 - val_acc: 0.9817
# Epoch 152/1536
# Epoch 00151: val_loss did not improve
# 0s - loss: 0.0249 - acc: 0.9920 - val_loss: 0.0630 - val_acc: 0.9798
# Epoch 153/1536
# Epoch 00152: val_loss did not improve
# 0s - loss: 0.0261 - acc: 0.9906 - val_loss: 0.0623 - val_acc: 0.9793
# Epoch 154/1536
# Epoch 00153: val_loss did not improve
# 0s - loss: 0.0871 - acc: 0.9744 - val_loss: 0.4310 - val_acc: 0.9188
# Epoch 155/1536
# Epoch 00154: val_loss did not improve
# 0s - loss: 0.4955 - acc: 0.8968 - val_loss: 0.3953 - val_acc: 0.9180
# Epoch 156/1536
# Epoch 00155: val_loss did not improve
# 0s - loss: 0.1411 - acc: 0.9633 - val_loss: 0.0615 - val_acc: 0.9799
# Epoch 157/1536
# Epoch 00156: val_loss did not improve
# 0s - loss: 0.0254 - acc: 0.9916 - val_loss: 0.0666 - val_acc: 0.9775
# Epoch 158/1536
# Epoch 00157: val_loss did not improve
# 0s - loss: 0.0240 - acc: 0.9918 - val_loss: 0.0651 - val_acc: 0.9790
# Epoch 159/1536
# Epoch 00158: val_loss did not improve
# 0s - loss: 0.0232 - acc: 0.9925 - val_loss: 0.0794 - val_acc: 0.9757
# Epoch 160/1536
# Epoch 00159: val_loss did not improve
# 0s - loss: 0.5383 - acc: 0.8906 - val_loss: 0.7130 - val_acc: 0.8528
# Epoch 161/1536
# Epoch 00160: val_loss did not improve
# 0s - loss: 0.4154 - acc: 0.9117 - val_loss: 0.0773 - val_acc: 0.9770
# Epoch 162/1536
# Epoch 00161: val_loss did not improve
# 0s - loss: 0.0325 - acc: 0.9889 - val_loss: 0.0705 - val_acc: 0.9786
# Epoch 163/1536
# Epoch 00162: val_loss did not improve
# 0s - loss: 0.0291 - acc: 0.9903 - val_loss: 0.0685 - val_acc: 0.9787
# Epoch 164/1536
# Epoch 00163: val_loss did not improve
# 0s - loss: 0.0273 - acc: 0.9911 - val_loss: 0.0710 - val_acc: 0.9775
# Epoch 165/1536
# Epoch 00164: val_loss did not improve
# 0s - loss: 0.0474 - acc: 0.9842 - val_loss: 1.1721 - val_acc: 0.8454
# Epoch 166/1536
# Epoch 00165: val_loss did not improve
# 0s - loss: 2.2910 - acc: 0.7194 - val_loss: 0.2296 - val_acc: 0.9416
# Epoch 167/1536
# Epoch 00166: val_loss did not improve
# 0s - loss: 0.0899 - acc: 0.9718 - val_loss: 0.0744 - val_acc: 0.9783
# Epoch 168/1536
# Epoch 00167: val_loss did not improve
# 0s - loss: 0.0417 - acc: 0.9856 - val_loss: 0.0684 - val_acc: 0.9794
# Epoch 169/1536
# Epoch 00168: val_loss did not improve
# 0s - loss: 0.0349 - acc: 0.9883 - val_loss: 0.0637 - val_acc: 0.9806
# Epoch 170/1536
# Epoch 00169: val_loss did not improve
# 0s - loss: 0.0309 - acc: 0.9892 - val_loss: 0.0628 - val_acc: 0.9810
# Epoch 171/1536
# Epoch 00170: val_loss did not improve
# 0s - loss: 0.0286 - acc: 0.9902 - val_loss: 0.0596 - val_acc: 0.9820
# Epoch 172/1536
# Epoch 00171: val_loss did not improve
# 0s - loss: 0.0289 - acc: 0.9898 - val_loss: 0.0696 - val_acc: 0.9781
# Epoch 173/1536
# Epoch 00172: val_loss did not improve
# 0s - loss: 0.2270 - acc: 0.9549 - val_loss: 0.9698 - val_acc: 0.8205
# Epoch 174/1536
# Epoch 00173: val_loss did not improve
# 0s - loss: 0.8387 - acc: 0.8518 - val_loss: 0.0735 - val_acc: 0.9769
# Epoch 175/1536
# Epoch 00174: val_loss did not improve
# 0s - loss: 0.0310 - acc: 0.9893 - val_loss: 0.0658 - val_acc: 0.9806
# Epoch 176/1536
# Epoch 00175: val_loss did not improve
# 0s - loss: 0.0309 - acc: 0.9896 - val_loss: 0.0681 - val_acc: 0.9791
# Epoch 177/1536
# Epoch 00176: val_loss did not improve
# 0s - loss: 0.0275 - acc: 0.9905 - val_loss: 0.0608 - val_acc: 0.9813
# Epoch 178/1536
# Epoch 00177: val_loss did not improve
# 0s - loss: 0.1099 - acc: 0.9680 - val_loss: 0.8655 - val_acc: 0.8517
# Epoch 179/1536
# Epoch 00178: val_loss did not improve
# 0s - loss: 0.5374 - acc: 0.8913 - val_loss: 0.2374 - val_acc: 0.9340
# Epoch 180/1536
# Epoch 00179: val_loss improved from 0.05668 to 0.05442, saving model to saved_models/resnet50_rgbModel_197px_batch8192_epoch1536.hdf5
# 0s - loss: 0.0945 - acc: 0.9733 - val_loss: 0.0544 - val_acc: 0.9820
# Epoch 181/1536
# Epoch 00180: val_loss did not improve
# 0s - loss: 0.0243 - acc: 0.9921 - val_loss: 0.0587 - val_acc: 0.9808
# Epoch 182/1536
# Epoch 00181: val_loss did not improve
# 0s - loss: 0.0239 - acc: 0.9920 - val_loss: 0.0586 - val_acc: 0.9801
# Epoch 183/1536
# Epoch 00182: val_loss did not improve
# 0s - loss: 0.0945 - acc: 0.9713 - val_loss: 0.3215 - val_acc: 0.9256
# Epoch 184/1536
# Epoch 00183: val_loss did not improve
# 0s - loss: 0.3284 - acc: 0.9166 - val_loss: 0.3734 - val_acc: 0.9074
# Epoch 185/1536
# Epoch 00184: val_loss did not improve
# 0s - loss: 0.1604 - acc: 0.9570 - val_loss: 0.0579 - val_acc: 0.9821
# Epoch 186/1536
# Epoch 00185: val_loss did not improve
# 0s - loss: 0.0230 - acc: 0.9927 - val_loss: 0.0571 - val_acc: 0.9819
# Epoch 187/1536
# Epoch 00186: val_loss did not improve
# 0s - loss: 0.0236 - acc: 0.9924 - val_loss: 0.0685 - val_acc: 0.9795
# Epoch 188/1536
# Epoch 00187: val_loss did not improve
# 0s - loss: 0.2043 - acc: 0.9531 - val_loss: 0.4463 - val_acc: 0.9003
# Epoch 189/1536
# Epoch 00188: val_loss did not improve
# 0s - loss: 0.5737 - acc: 0.8732 - val_loss: 0.6234 - val_acc: 0.8868
# Epoch 190/1536
# Epoch 00189: val_loss did not improve
# 0s - loss: 0.2552 - acc: 0.9423 - val_loss: 0.0614 - val_acc: 0.9810
# Epoch 191/1536
# Epoch 00190: val_loss did not improve
# 0s - loss: 0.0280 - acc: 0.9911 - val_loss: 0.0599 - val_acc: 0.9817
# Epoch 192/1536
# Epoch 00191: val_loss did not improve
# 0s - loss: 0.0268 - acc: 0.9914 - val_loss: 0.0583 - val_acc: 0.9815
# Epoch 193/1536
# Epoch 00192: val_loss did not improve
# 0s - loss: 0.0273 - acc: 0.9908 - val_loss: 0.0630 - val_acc: 0.9807
# Epoch 194/1536
# Epoch 00193: val_loss did not improve
# 0s - loss: 0.0354 - acc: 0.9882 - val_loss: 0.2719 - val_acc: 0.9350
# Epoch 195/1536
# Epoch 00194: val_loss did not improve
# 0s - loss: 0.6116 - acc: 0.8783 - val_loss: 0.5439 - val_acc: 0.8775
# Epoch 196/1536
# Epoch 00195: val_loss did not improve
# 0s - loss: 0.2632 - acc: 0.9432 - val_loss: 0.0613 - val_acc: 0.9802
# Epoch 197/1536
# Epoch 00196: val_loss did not improve
# 0s - loss: 0.0289 - acc: 0.9911 - val_loss: 0.0582 - val_acc: 0.9813
# Epoch 198/1536
# Epoch 00197: val_loss did not improve
# 0s - loss: 0.0240 - acc: 0.9925 - val_loss: 0.0569 - val_acc: 0.9815
# Epoch 199/1536
# Epoch 00198: val_loss did not improve
# 0s - loss: 0.0243 - acc: 0.9925 - val_loss: 0.0748 - val_acc: 0.9759
# Epoch 200/1536
# Epoch 00199: val_loss did not improve
# 0s - loss: 0.2989 - acc: 0.9351 - val_loss: 0.9928 - val_acc: 0.8305
# Epoch 201/1536
# Epoch 00200: val_loss did not improve
# 0s - loss: 0.8089 - acc: 0.8623 - val_loss: 0.0705 - val_acc: 0.9788
# Epoch 202/1536
# Epoch 00201: val_loss did not improve
# 0s - loss: 0.0317 - acc: 0.9896 - val_loss: 0.0677 - val_acc: 0.9795
# Epoch 203/1536
# Epoch 00202: val_loss did not improve
# 0s - loss: 0.0285 - acc: 0.9907 - val_loss: 0.0641 - val_acc: 0.9806
# Epoch 204/1536
# Epoch 00203: val_loss did not improve
# 0s - loss: 0.0252 - acc: 0.9917 - val_loss: 0.0600 - val_acc: 0.9820
# Epoch 205/1536
# Epoch 00204: val_loss did not improve
# 0s - loss: 0.0246 - acc: 0.9918 - val_loss: 0.0880 - val_acc: 0.9730
# Epoch 206/1536
# Epoch 00205: val_loss did not improve
# 0s - loss: 0.1903 - acc: 0.9544 - val_loss: 0.4475 - val_acc: 0.8975
# Epoch 207/1536
# Epoch 00206: val_loss did not improve
# 0s - loss: 0.5389 - acc: 0.8788 - val_loss: 0.1277 - val_acc: 0.9626
# Epoch 208/1536
# Epoch 00207: val_loss did not improve
# 0s - loss: 0.0410 - acc: 0.9864 - val_loss: 0.0593 - val_acc: 0.9809
# Epoch 209/1536
# Epoch 00208: val_loss did not improve
# 0s - loss: 0.0267 - acc: 0.9914 - val_loss: 0.0608 - val_acc: 0.9808
# Epoch 210/1536
# Epoch 00209: val_loss did not improve
# 0s - loss: 0.0245 - acc: 0.9922 - val_loss: 0.0643 - val_acc: 0.9788
# Epoch 211/1536
# Epoch 00210: val_loss did not improve
# 0s - loss: 0.0271 - acc: 0.9906 - val_loss: 0.0650 - val_acc: 0.9795
# Epoch 212/1536
# Epoch 00211: val_loss did not improve
# 0s - loss: 0.0435 - acc: 0.9854 - val_loss: 0.8133 - val_acc: 0.9059
# Epoch 213/1536
# Epoch 00212: val_loss did not improve
# 0s - loss: 1.1820 - acc: 0.8149 - val_loss: 0.6305 - val_acc: 0.8662
# Epoch 214/1536
# Epoch 00213: val_loss did not improve
# 0s - loss: 0.2850 - acc: 0.9349 - val_loss: 0.0639 - val_acc: 0.9804
# Epoch 215/1536
# Epoch 00214: val_loss did not improve
# 0s - loss: 0.0283 - acc: 0.9904 - val_loss: 0.0635 - val_acc: 0.9797
# Epoch 216/1536
# Epoch 00215: val_loss did not improve
# 0s - loss: 0.0260 - acc: 0.9911 - val_loss: 0.0604 - val_acc: 0.9817
# Epoch 217/1536
# Epoch 00216: val_loss did not improve
# 0s - loss: 0.0231 - acc: 0.9922 - val_loss: 0.0639 - val_acc: 0.9792
# Epoch 218/1536
# Epoch 00217: val_loss did not improve
# 0s - loss: 0.0232 - acc: 0.9922 - val_loss: 0.0579 - val_acc: 0.9818
# Epoch 219/1536
# Epoch 00218: val_loss did not improve
# 0s - loss: 0.0247 - acc: 0.9919 - val_loss: 0.0720 - val_acc: 0.9776
# Epoch 220/1536
# Epoch 00219: val_loss did not improve
# 0s - loss: 0.3013 - acc: 0.9450 - val_loss: 0.7530 - val_acc: 0.8725
# Epoch 221/1536
# Epoch 00220: val_loss did not improve
# 0s - loss: 0.3978 - acc: 0.9158 - val_loss: 0.0625 - val_acc: 0.9808
# Epoch 222/1536
# Epoch 00221: val_loss did not improve
# 0s - loss: 0.0266 - acc: 0.9916 - val_loss: 0.0606 - val_acc: 0.9822
# Epoch 223/1536
# Epoch 00222: val_loss did not improve
# 0s - loss: 0.0257 - acc: 0.9911 - val_loss: 0.0572 - val_acc: 0.9824
# Epoch 224/1536
# Epoch 00223: val_loss did not improve
# 0s - loss: 0.0229 - acc: 0.9921 - val_loss: 0.0776 - val_acc: 0.9765
# Epoch 225/1536
# Epoch 00224: val_loss did not improve
# 0s - loss: 0.3823 - acc: 0.9332 - val_loss: 1.1606 - val_acc: 0.8216
# Epoch 226/1536
# Epoch 00225: val_loss did not improve
# 0s - loss: 1.6211 - acc: 0.7860 - val_loss: 0.0857 - val_acc: 0.9752
# Epoch 227/1536
# Epoch 00226: val_loss did not improve
# 0s - loss: 0.0437 - acc: 0.9853 - val_loss: 0.0656 - val_acc: 0.9808
# Epoch 228/1536
# Epoch 00227: val_loss did not improve
# 0s - loss: 0.0315 - acc: 0.9891 - val_loss: 0.0621 - val_acc: 0.9803
# Epoch 229/1536
# Epoch 00228: val_loss did not improve
# 0s - loss: 0.0283 - acc: 0.9899 - val_loss: 0.0589 - val_acc: 0.9827
# Epoch 230/1536
# Epoch 00229: val_loss did not improve
# 0s - loss: 0.0262 - acc: 0.9913 - val_loss: 0.0592 - val_acc: 0.9818
# Epoch 231/1536
# Epoch 00230: val_loss did not improve
# 0s - loss: 0.0264 - acc: 0.9910 - val_loss: 0.0691 - val_acc: 0.9780
# Epoch 232/1536
# Epoch 00231: val_loss did not improve
# 0s - loss: 0.1022 - acc: 0.9750 - val_loss: 0.2325 - val_acc: 0.9401
# Epoch 233/1536
# Epoch 00232: val_loss did not improve
# 0s - loss: 0.4870 - acc: 0.9046 - val_loss: 0.3029 - val_acc: 0.9235
# Epoch 234/1536
# Epoch 00233: val_loss did not improve
# 0s - loss: 0.1085 - acc: 0.9682 - val_loss: 0.0634 - val_acc: 0.9797
# Epoch 235/1536
# Epoch 00234: val_loss did not improve
# 0s - loss: 0.0234 - acc: 0.9927 - val_loss: 0.0617 - val_acc: 0.9802
# Epoch 236/1536
# Epoch 00235: val_loss did not improve
# 0s - loss: 0.0224 - acc: 0.9925 - val_loss: 0.0572 - val_acc: 0.9813
# Epoch 237/1536
# Epoch 00236: val_loss did not improve
# 0s - loss: 0.0219 - acc: 0.9927 - val_loss: 0.0643 - val_acc: 0.9804
# Epoch 238/1536
# Epoch 00237: val_loss did not improve
# 0s - loss: 0.1698 - acc: 0.9601 - val_loss: 0.5559 - val_acc: 0.8860
# Epoch 239/1536
# Epoch 00238: val_loss did not improve
# 0s - loss: 1.0141 - acc: 0.8239 - val_loss: 0.1220 - val_acc: 0.9644
# Epoch 240/1536
# Epoch 00239: val_loss did not improve
# 0s - loss: 0.0438 - acc: 0.9844 - val_loss: 0.0636 - val_acc: 0.9806
# Epoch 241/1536
# Epoch 00240: val_loss did not improve
# 0s - loss: 0.0293 - acc: 0.9899 - val_loss: 0.0627 - val_acc: 0.9812
# Epoch 242/1536
# Epoch 00241: val_loss did not improve
# 0s - loss: 0.0249 - acc: 0.9917 - val_loss: 0.0627 - val_acc: 0.9808
# Epoch 243/1536
# Epoch 00242: val_loss did not improve
# 0s - loss: 0.0242 - acc: 0.9914 - val_loss: 0.0716 - val_acc: 0.9786
# Epoch 244/1536
# Epoch 00243: val_loss did not improve
# 0s - loss: 0.0297 - acc: 0.9894 - val_loss: 0.1968 - val_acc: 0.9415
# Epoch 245/1536
# Epoch 00244: val_loss did not improve
# 0s - loss: 0.5638 - acc: 0.8855 - val_loss: 0.4649 - val_acc: 0.8834
# Epoch 246/1536
# Epoch 00245: val_loss did not improve
# 0s - loss: 0.1964 - acc: 0.9483 - val_loss: 0.0572 - val_acc: 0.9815
# Epoch 247/1536
# Epoch 00246: val_loss did not improve
# 0s - loss: 0.0248 - acc: 0.9915 - val_loss: 0.0554 - val_acc: 0.9821
# Epoch 248/1536
# Epoch 00247: val_loss did not improve
# 0s - loss: 0.0222 - acc: 0.9927 - val_loss: 0.0580 - val_acc: 0.9822
# Epoch 249/1536
# Epoch 00248: val_loss did not improve
# 0s - loss: 0.0237 - acc: 0.9918 - val_loss: 0.0779 - val_acc: 0.9750
# Epoch 250/1536
# Epoch 00249: val_loss did not improve
# 0s - loss: 0.2341 - acc: 0.9428 - val_loss: 0.7132 - val_acc: 0.8545
# Epoch 251/1536
# Epoch 00250: val_loss did not improve
# 0s - loss: 0.3690 - acc: 0.9156 - val_loss: 0.0641 - val_acc: 0.9791
# Epoch 252/1536
# Epoch 00251: val_loss did not improve
# 0s - loss: 0.0259 - acc: 0.9916 - val_loss: 0.0635 - val_acc: 0.9798
# Epoch 253/1536
# Epoch 00252: val_loss did not improve
# 0s - loss: 0.0234 - acc: 0.9922 - val_loss: 0.0600 - val_acc: 0.9809
# Epoch 254/1536
# Epoch 00253: val_loss did not improve
# 0s - loss: 0.0238 - acc: 0.9923 - val_loss: 0.1065 - val_acc: 0.9677
# Epoch 255/1536
# Epoch 00254: val_loss did not improve
# 0s - loss: 0.7103 - acc: 0.8844 - val_loss: 2.1216 - val_acc: 0.7286
# Epoch 256/1536
# Epoch 00255: val_loss did not improve
# 0s - loss: 1.4035 - acc: 0.8248 - val_loss: 0.0786 - val_acc: 0.9762
# Epoch 257/1536
# Epoch 00256: val_loss did not improve
# 0s - loss: 0.0379 - acc: 0.9866 - val_loss: 0.0698 - val_acc: 0.9791
# Epoch 258/1536
# Epoch 00257: val_loss did not improve
# 0s - loss: 0.0307 - acc: 0.9898 - val_loss: 0.0693 - val_acc: 0.9790
# Epoch 259/1536
# Epoch 00258: val_loss did not improve
# 0s - loss: 0.0301 - acc: 0.9894 - val_loss: 0.0696 - val_acc: 0.9798
# Epoch 260/1536
# Epoch 00259: val_loss did not improve
# 0s - loss: 0.0275 - acc: 0.9908 - val_loss: 0.0664 - val_acc: 0.9797
# Epoch 261/1536
# Epoch 00260: val_loss did not improve
# 0s - loss: 0.0240 - acc: 0.9919 - val_loss: 0.0707 - val_acc: 0.9791
# Epoch 262/1536
# Epoch 00261: val_loss did not improve
# 0s - loss: 0.0264 - acc: 0.9911 - val_loss: 0.0858 - val_acc: 0.9731
# Epoch 263/1536
# Epoch 00262: val_loss did not improve
# 0s - loss: 0.3875 - acc: 0.9260 - val_loss: 0.9073 - val_acc: 0.8415
# Epoch 264/1536
# Epoch 00263: val_loss did not improve
# 0s - loss: 0.3364 - acc: 0.9322 - val_loss: 0.0623 - val_acc: 0.9798
# Epoch 265/1536
# Epoch 00264: val_loss did not improve
# 0s - loss: 0.0239 - acc: 0.9916 - val_loss: 0.0669 - val_acc: 0.9788
# Epoch 266/1536
# Epoch 00265: val_loss did not improve
# 0s - loss: 0.0237 - acc: 0.9918 - val_loss: 0.0680 - val_acc: 0.9785
# Epoch 267/1536
# Epoch 00266: val_loss did not improve
# 0s - loss: 0.0239 - acc: 0.9916 - val_loss: 0.0658 - val_acc: 0.9795
# Epoch 268/1536
# Epoch 00267: val_loss did not improve
# 0s - loss: 0.1211 - acc: 0.9702 - val_loss: 0.7891 - val_acc: 0.8424
# Epoch 269/1536
# Epoch 00268: val_loss did not improve
# 0s - loss: 1.3369 - acc: 0.8003 - val_loss: 0.0812 - val_acc: 0.9745
# Epoch 270/1536
# Epoch 00269: val_loss did not improve
# 0s - loss: 0.0348 - acc: 0.9885 - val_loss: 0.0659 - val_acc: 0.9793
# Epoch 271/1536
# Epoch 00270: val_loss did not improve
# 0s - loss: 0.0263 - acc: 0.9908 - val_loss: 0.0636 - val_acc: 0.9807
# Epoch 272/1536
# Epoch 00271: val_loss did not improve
# 0s - loss: 0.0270 - acc: 0.9909 - val_loss: 0.0633 - val_acc: 0.9803
# Epoch 273/1536
# Epoch 00272: val_loss did not improve
# 0s - loss: 0.0231 - acc: 0.9922 - val_loss: 0.0679 - val_acc: 0.9794
# Epoch 274/1536
# Epoch 00273: val_loss did not improve
# 0s - loss: 0.0231 - acc: 0.9921 - val_loss: 0.0719 - val_acc: 0.9778
# Epoch 275/1536
# Epoch 00274: val_loss did not improve
# 0s - loss: 0.6097 - acc: 0.9009 - val_loss: 1.5800 - val_acc: 0.8256
# Epoch 276/1536
# Epoch 00275: val_loss did not improve
# 0s - loss: 0.8353 - acc: 0.8866 - val_loss: 0.0743 - val_acc: 0.9788
# Epoch 277/1536
# Epoch 00276: val_loss did not improve
# 0s - loss: 0.0316 - acc: 0.9886 - val_loss: 0.0676 - val_acc: 0.9807
# Epoch 278/1536
# Epoch 00277: val_loss did not improve
# 0s - loss: 0.0247 - acc: 0.9916 - val_loss: 0.0650 - val_acc: 0.9810
# Epoch 279/1536
# Epoch 00278: val_loss did not improve
# 0s - loss: 0.0248 - acc: 0.9916 - val_loss: 0.0650 - val_acc: 0.9813
# Epoch 280/1536
# Epoch 00279: val_loss did not improve
# 0s - loss: 0.0206 - acc: 0.9934 - val_loss: 0.0638 - val_acc: 0.9824
# Epoch 281/1536
# Epoch 00280: val_loss did not improve
# 0s - loss: 0.0227 - acc: 0.9920 - val_loss: 0.1365 - val_acc: 0.9630
# Epoch 282/1536
# Epoch 00281: val_loss did not improve
# 0s - loss: 0.7494 - acc: 0.8820 - val_loss: 2.0717 - val_acc: 0.7611
# Epoch 283/1536
# Epoch 00282: val_loss did not improve
# 0s - loss: 0.8020 - acc: 0.8822 - val_loss: 0.0741 - val_acc: 0.9791
# Epoch 284/1536
# Epoch 00283: val_loss did not improve
# 0s - loss: 0.0293 - acc: 0.9899 - val_loss: 0.0656 - val_acc: 0.9798
# Epoch 285/1536
# Epoch 00284: val_loss did not improve
# 0s - loss: 0.0244 - acc: 0.9916 - val_loss: 0.0628 - val_acc: 0.9806
# Epoch 286/1536
# Epoch 00285: val_loss did not improve
# 0s - loss: 0.0229 - acc: 0.9919 - val_loss: 0.0635 - val_acc: 0.9800
# Epoch 287/1536
# Epoch 00286: val_loss did not improve
# 0s - loss: 0.0218 - acc: 0.9927 - val_loss: 0.0589 - val_acc: 0.9811
# Epoch 288/1536
# Epoch 00287: val_loss did not improve
# 0s - loss: 0.0226 - acc: 0.9922 - val_loss: 0.1256 - val_acc: 0.9681
# Epoch 289/1536
# Epoch 00288: val_loss did not improve
# 0s - loss: 0.5309 - acc: 0.9126 - val_loss: 0.4289 - val_acc: 0.9048
# Epoch 290/1536
# Epoch 00289: val_loss did not improve
# 0s - loss: 0.2198 - acc: 0.9453 - val_loss: 0.0620 - val_acc: 0.9815
# Epoch 291/1536
# Epoch 00290: val_loss did not improve
# 0s - loss: 0.0208 - acc: 0.9925 - val_loss: 0.0576 - val_acc: 0.9816
# Epoch 292/1536
# Epoch 00291: val_loss did not improve
# 0s - loss: 0.0203 - acc: 0.9932 - val_loss: 0.0654 - val_acc: 0.9801
# Epoch 293/1536
# Epoch 00292: val_loss did not improve
# 0s - loss: 0.0196 - acc: 0.9934 - val_loss: 0.0627 - val_acc: 0.9808
# Epoch 294/1536
# Epoch 00293: val_loss did not improve
# 0s - loss: 0.0378 - acc: 0.9889 - val_loss: 0.6167 - val_acc: 0.9208
# Epoch 295/1536
# Epoch 00294: val_loss did not improve
# 0s - loss: 1.0449 - acc: 0.8372 - val_loss: 0.1522 - val_acc: 0.9569
# Epoch 296/1536
# Epoch 00295: val_loss did not improve
# 0s - loss: 0.0485 - acc: 0.9839 - val_loss: 0.0611 - val_acc: 0.9812
# Epoch 297/1536
# Epoch 00296: val_loss did not improve
# 0s - loss: 0.0243 - acc: 0.9917 - val_loss: 0.0601 - val_acc: 0.9816
# Epoch 298/1536
# Epoch 00297: val_loss did not improve
# 0s - loss: 0.0221 - acc: 0.9924 - val_loss: 0.0606 - val_acc: 0.9817
# Epoch 299/1536
# Epoch 00298: val_loss did not improve
# 0s - loss: 0.0199 - acc: 0.9930 - val_loss: 0.0609 - val_acc: 0.9815
# Epoch 300/1536
# Epoch 00299: val_loss did not improve
# 0s - loss: 0.0263 - acc: 0.9906 - val_loss: 0.1828 - val_acc: 0.9541
# Epoch 301/1536
# Epoch 00300: val_loss did not improve
# 0s - loss: 0.6223 - acc: 0.8881 - val_loss: 1.1908 - val_acc: 0.8160
# Epoch 302/1536
# Epoch 00301: val_loss did not improve
# 0s - loss: 0.5637 - acc: 0.9039 - val_loss: 0.0664 - val_acc: 0.9791
# Epoch 303/1536
# Epoch 00302: val_loss did not improve
# 0s - loss: 0.0287 - acc: 0.9905 - val_loss: 0.0616 - val_acc: 0.9816
# Epoch 304/1536
# Epoch 00303: val_loss did not improve
# 0s - loss: 0.0265 - acc: 0.9910 - val_loss: 0.0605 - val_acc: 0.9805
# Epoch 305/1536
# Epoch 00304: val_loss did not improve
# 0s - loss: 0.0234 - acc: 0.9921 - val_loss: 0.0684 - val_acc: 0.9797
# Epoch 306/1536
# Epoch 00305: val_loss did not improve
# 0s - loss: 0.0253 - acc: 0.9915 - val_loss: 0.0589 - val_acc: 0.9821
# Epoch 307/1536
# Epoch 00306: val_loss did not improve
# 0s - loss: 0.0215 - acc: 0.9928 - val_loss: 0.0655 - val_acc: 0.9797
# Epoch 308/1536
# Epoch 00307: val_loss did not improve
# 0s - loss: 0.7919 - acc: 0.8870 - val_loss: 3.6045 - val_acc: 0.6581
# Epoch 309/1536
# Epoch 00308: val_loss did not improve
# 0s - loss: 1.5348 - acc: 0.8240 - val_loss: 0.0765 - val_acc: 0.9775
# Epoch 310/1536
# Epoch 00309: val_loss did not improve
# 0s - loss: 0.0349 - acc: 0.9879 - val_loss: 0.0674 - val_acc: 0.9809
# Epoch 311/1536
# Epoch 00310: val_loss did not improve
# 0s - loss: 0.0312 - acc: 0.9889 - val_loss: 0.0654 - val_acc: 0.9806
# Epoch 312/1536
# Epoch 00311: val_loss did not improve
# 0s - loss: 0.0271 - acc: 0.9904 - val_loss: 0.0645 - val_acc: 0.9815
# Epoch 313/1536
# Epoch 00312: val_loss did not improve
# 0s - loss: 0.0268 - acc: 0.9906 - val_loss: 0.0636 - val_acc: 0.9815
# Epoch 314/1536
# Epoch 00313: val_loss did not improve
# 0s - loss: 0.0232 - acc: 0.9915 - val_loss: 0.0604 - val_acc: 0.9814
# Epoch 315/1536
# Epoch 00314: val_loss did not improve
# 0s - loss: 0.0219 - acc: 0.9927 - val_loss: 0.0933 - val_acc: 0.9739
# Epoch 316/1536
# Epoch 00315: val_loss did not improve
# 0s - loss: 0.5767 - acc: 0.9051 - val_loss: 0.3118 - val_acc: 0.9329
# Epoch 317/1536
# Epoch 00316: val_loss did not improve
# 0s - loss: 0.2987 - acc: 0.9427 - val_loss: 0.0650 - val_acc: 0.9800
# Epoch 318/1536
# Epoch 00317: val_loss did not improve
# 0s - loss: 0.0231 - acc: 0.9925 - val_loss: 0.0597 - val_acc: 0.9820
# Epoch 319/1536
# Epoch 00318: val_loss did not improve
# 0s - loss: 0.0222 - acc: 0.9929 - val_loss: 0.0583 - val_acc: 0.9820
# Epoch 320/1536
# Epoch 00319: val_loss did not improve
# 0s - loss: 0.0207 - acc: 0.9935 - val_loss: 0.0750 - val_acc: 0.9777
# Epoch 321/1536
# Epoch 00320: val_loss did not improve
# 0s - loss: 0.3305 - acc: 0.9400 - val_loss: 1.2221 - val_acc: 0.8483
# Epoch 322/1536
# Epoch 00321: val_loss did not improve
# 0s - loss: 0.9483 - acc: 0.8649 - val_loss: 0.0663 - val_acc: 0.9807
# Epoch 323/1536
# Epoch 00322: val_loss did not improve
# 0s - loss: 0.0250 - acc: 0.9916 - val_loss: 0.0652 - val_acc: 0.9807
# Epoch 324/1536
# Epoch 00323: val_loss did not improve
# 0s - loss: 0.0250 - acc: 0.9914 - val_loss: 0.0631 - val_acc: 0.9808
# Epoch 325/1536
# Epoch 00324: val_loss did not improve
# 0s - loss: 0.0234 - acc: 0.9916 - val_loss: 0.0711 - val_acc: 0.9792
# Epoch 326/1536
# Epoch 00325: val_loss did not improve
# 0s - loss: 0.0242 - acc: 0.9916 - val_loss: 0.0873 - val_acc: 0.9745
# Epoch 327/1536
# Epoch 00326: val_loss did not improve
# 0s - loss: 0.2829 - acc: 0.9327 - val_loss: 0.3974 - val_acc: 0.9115
# Epoch 328/1536
# Epoch 00327: val_loss did not improve
# 0s - loss: 0.2786 - acc: 0.9294 - val_loss: 0.0686 - val_acc: 0.9807
# Epoch 329/1536
# Epoch 00328: val_loss did not improve
# 0s - loss: 0.0206 - acc: 0.9932 - val_loss: 0.0622 - val_acc: 0.9808
# Epoch 330/1536
# Epoch 00329: val_loss did not improve
# 0s - loss: 0.0177 - acc: 0.9940 - val_loss: 0.0639 - val_acc: 0.9815
# Epoch 331/1536
# Epoch 00330: val_loss did not improve
# 0s - loss: 0.0177 - acc: 0.9939 - val_loss: 0.0573 - val_acc: 0.9825
# Epoch 332/1536
# Epoch 00331: val_loss did not improve
# 0s - loss: 0.0177 - acc: 0.9947 - val_loss: 0.0820 - val_acc: 0.9753
# Epoch 333/1536
# Epoch 00332: val_loss did not improve
# 0s - loss: 0.6827 - acc: 0.8885 - val_loss: 1.1118 - val_acc: 0.8205
# Epoch 334/1536
# Epoch 00333: val_loss did not improve
# 0s - loss: 0.4500 - acc: 0.9158 - val_loss: 0.0690 - val_acc: 0.9788
# Epoch 335/1536
# Epoch 00334: val_loss did not improve
# 0s - loss: 0.0253 - acc: 0.9911 - val_loss: 0.0657 - val_acc: 0.9802
# Epoch 336/1536
# Epoch 00335: val_loss did not improve
# 0s - loss: 0.0251 - acc: 0.9912 - val_loss: 0.0679 - val_acc: 0.9791
# Epoch 337/1536
# Epoch 00336: val_loss did not improve
# 0s - loss: 0.0228 - acc: 0.9916 - val_loss: 0.0623 - val_acc: 0.9796
# Epoch 338/1536
# Epoch 00337: val_loss did not improve
# 0s - loss: 0.0254 - acc: 0.9914 - val_loss: 0.4188 - val_acc: 0.9192
# Epoch 339/1536
# Epoch 00338: val_loss did not improve
# 0s - loss: 0.5963 - acc: 0.8869 - val_loss: 0.3769 - val_acc: 0.9202
# Epoch 340/1536
# Epoch 00339: val_loss did not improve
# 0s - loss: 0.1676 - acc: 0.9583 - val_loss: 0.0600 - val_acc: 0.9808
# Epoch 341/1536
# Epoch 00340: val_loss did not improve
# 0s - loss: 0.0211 - acc: 0.9930 - val_loss: 0.0568 - val_acc: 0.9809
# Epoch 342/1536
# Epoch 00341: val_loss did not improve
# 0s - loss: 0.0200 - acc: 0.9928 - val_loss: 0.0606 - val_acc: 0.9816
# Epoch 343/1536
# Epoch 00342: val_loss did not improve
# 0s - loss: 0.0181 - acc: 0.9943 - val_loss: 0.0557 - val_acc: 0.9826
# Epoch 344/1536
# Epoch 00343: val_loss did not improve
# 0s - loss: 0.0207 - acc: 0.9933 - val_loss: 0.0725 - val_acc: 0.9790
# Epoch 345/1536
# Epoch 00344: val_loss did not improve
# 0s - loss: 0.3611 - acc: 0.9295 - val_loss: 0.6484 - val_acc: 0.8802
# Epoch 346/1536
# Epoch 00345: val_loss did not improve
# 0s - loss: 0.3042 - acc: 0.9299 - val_loss: 0.0583 - val_acc: 0.9825
# Epoch 347/1536
# Epoch 00346: val_loss did not improve
# 0s - loss: 0.0200 - acc: 0.9934 - val_loss: 0.0553 - val_acc: 0.9824
# Epoch 348/1536
# Epoch 00347: val_loss did not improve
# 0s - loss: 0.0177 - acc: 0.9944 - val_loss: 0.0614 - val_acc: 0.9800
# Epoch 349/1536
# Epoch 00348: val_loss did not improve
# 0s - loss: 0.0200 - acc: 0.9931 - val_loss: 0.0546 - val_acc: 0.9822
# Epoch 350/1536
# Epoch 00349: val_loss did not improve
# 0s - loss: 0.0458 - acc: 0.9882 - val_loss: 0.7443 - val_acc: 0.8951
# Epoch 351/1536
# Epoch 00350: val_loss did not improve
# 0s - loss: 1.2275 - acc: 0.8172 - val_loss: 0.3535 - val_acc: 0.9195
# Epoch 352/1536
# Epoch 00351: val_loss did not improve
# 0s - loss: 0.1091 - acc: 0.9708 - val_loss: 0.0673 - val_acc: 0.9794
# Epoch 353/1536
# Epoch 00352: val_loss did not improve
# 0s - loss: 0.0249 - acc: 0.9915 - val_loss: 0.0626 - val_acc: 0.9808
# Epoch 354/1536
# Epoch 00353: val_loss did not improve
# 0s - loss: 0.0235 - acc: 0.9925 - val_loss: 0.0637 - val_acc: 0.9816
# Epoch 355/1536
# Epoch 00354: val_loss did not improve
# 0s - loss: 0.0220 - acc: 0.9928 - val_loss: 0.0629 - val_acc: 0.9818
# Epoch 356/1536
# Epoch 00355: val_loss did not improve
# 0s - loss: 0.0207 - acc: 0.9930 - val_loss: 0.0655 - val_acc: 0.9804
# Epoch 357/1536
# Epoch 00356: val_loss did not improve
# 0s - loss: 0.0267 - acc: 0.9905 - val_loss: 0.2825 - val_acc: 0.9346
# Epoch 358/1536
# Epoch 00357: val_loss did not improve
# 0s - loss: 0.6412 - acc: 0.8943 - val_loss: 0.8383 - val_acc: 0.8403
# Epoch 359/1536
# Epoch 00358: val_loss did not improve
# 0s - loss: 0.5289 - acc: 0.9015 - val_loss: 0.0627 - val_acc: 0.9821
# Epoch 360/1536
# Epoch 00359: val_loss did not improve
# 0s - loss: 0.0246 - acc: 0.9918 - val_loss: 0.0578 - val_acc: 0.9832
# Epoch 361/1536
# Epoch 00360: val_loss did not improve
# 0s - loss: 0.0219 - acc: 0.9929 - val_loss: 0.0575 - val_acc: 0.9836
# Epoch 362/1536
# Epoch 00361: val_loss did not improve
# 0s - loss: 0.0198 - acc: 0.9934 - val_loss: 0.0587 - val_acc: 0.9823
# Epoch 363/1536
# Epoch 00362: val_loss did not improve
# 0s - loss: 0.0206 - acc: 0.9930 - val_loss: 0.0648 - val_acc: 0.9811
# Epoch 364/1536
# Epoch 00363: val_loss did not improve
# 0s - loss: 0.0198 - acc: 0.9935 - val_loss: 0.0704 - val_acc: 0.9788
# Epoch 365/1536
# Epoch 00364: val_loss did not improve
# 0s - loss: 0.3314 - acc: 0.9441 - val_loss: 3.1868 - val_acc: 0.7461
# Epoch 366/1536
# Epoch 00365: val_loss did not improve
# 0s - loss: 1.7066 - acc: 0.7943 - val_loss: 0.0751 - val_acc: 0.9773
# Epoch 367/1536
# Epoch 00366: val_loss did not improve
# 0s - loss: 0.0310 - acc: 0.9891 - val_loss: 0.0618 - val_acc: 0.9811
# Epoch 368/1536
# Epoch 00367: val_loss did not improve
# 0s - loss: 0.0264 - acc: 0.9909 - val_loss: 0.0603 - val_acc: 0.9808
# Epoch 369/1536
# Epoch 00368: val_loss did not improve
# 0s - loss: 0.0234 - acc: 0.9924 - val_loss: 0.0580 - val_acc: 0.9814
# Epoch 370/1536
# Epoch 00369: val_loss did not improve
# 0s - loss: 0.0211 - acc: 0.9929 - val_loss: 0.0579 - val_acc: 0.9821
# Epoch 371/1536
# Epoch 00370: val_loss did not improve
# 0s - loss: 0.0173 - acc: 0.9941 - val_loss: 0.0575 - val_acc: 0.9831
# Epoch 372/1536
# Epoch 00371: val_loss did not improve
# 0s - loss: 0.0203 - acc: 0.9929 - val_loss: 0.0828 - val_acc: 0.9745
# Epoch 373/1536
# Epoch 00372: val_loss did not improve
# 0s - loss: 0.2218 - acc: 0.9574 - val_loss: 0.7552 - val_acc: 0.8650
# Epoch 374/1536
# Epoch 00373: val_loss did not improve
# 0s - loss: 0.6092 - acc: 0.8975 - val_loss: 0.0641 - val_acc: 0.9806
# Epoch 375/1536
# Epoch 00374: val_loss did not improve
# 0s - loss: 0.0233 - acc: 0.9924 - val_loss: 0.0630 - val_acc: 0.9819
# Epoch 376/1536
# Epoch 00375: val_loss did not improve
# 0s - loss: 0.0202 - acc: 0.9932 - val_loss: 0.0626 - val_acc: 0.9813
# Epoch 377/1536
# Epoch 00376: val_loss did not improve
# 0s - loss: 0.0209 - acc: 0.9929 - val_loss: 0.0705 - val_acc: 0.9794
# Epoch 378/1536
# Epoch 00377: val_loss did not improve
# 0s - loss: 0.0605 - acc: 0.9818 - val_loss: 0.4991 - val_acc: 0.9073
# Epoch 379/1536
# Epoch 00378: val_loss did not improve
# 0s - loss: 0.4110 - acc: 0.9103 - val_loss: 0.3610 - val_acc: 0.9128
# Epoch 380/1536
# Epoch 00379: val_loss did not improve
# 0s - loss: 0.1698 - acc: 0.9558 - val_loss: 0.0586 - val_acc: 0.9816
# Epoch 381/1536
# Epoch 00380: val_loss did not improve
# 0s - loss: 0.0189 - acc: 0.9937 - val_loss: 0.0563 - val_acc: 0.9825
# Epoch 382/1536
# Epoch 00381: val_loss did not improve
# 0s - loss: 0.0180 - acc: 0.9940 - val_loss: 0.0579 - val_acc: 0.9817
# Epoch 383/1536
# Epoch 00382: val_loss did not improve
# 0s - loss: 0.0192 - acc: 0.9937 - val_loss: 0.0683 - val_acc: 0.9775
# Epoch 384/1536
# Epoch 00383: val_loss did not improve
# 0s - loss: 0.5424 - acc: 0.9235 - val_loss: 0.9003 - val_acc: 0.8647
# Epoch 385/1536
# Epoch 00384: val_loss did not improve
# 0s - loss: 0.2968 - acc: 0.9456 - val_loss: 0.0620 - val_acc: 0.9805
# Epoch 386/1536
# Epoch 00385: val_loss did not improve
# 0s - loss: 0.0221 - acc: 0.9929 - val_loss: 0.0608 - val_acc: 0.9822
# Epoch 387/1536
# Epoch 00386: val_loss did not improve
# 0s - loss: 0.0221 - acc: 0.9927 - val_loss: 0.0620 - val_acc: 0.9813
# Epoch 388/1536
# Epoch 00387: val_loss did not improve
# 0s - loss: 0.0228 - acc: 0.9924 - val_loss: 0.0630 - val_acc: 0.9800
# Epoch 389/1536
# Epoch 00388: val_loss did not improve
# 0s - loss: 0.1337 - acc: 0.9706 - val_loss: 0.2338 - val_acc: 0.9453
# Epoch 390/1536
# Epoch 00389: val_loss did not improve
# 0s - loss: 0.9042 - acc: 0.8668 - val_loss: 0.6278 - val_acc: 0.8861
# Epoch 391/1536
# Epoch 00390: val_loss did not improve
# 0s - loss: 0.1809 - acc: 0.9628 - val_loss: 0.0641 - val_acc: 0.9823
# Epoch 392/1536
# Epoch 00391: val_loss did not improve
# 0s - loss: 0.0235 - acc: 0.9922 - val_loss: 0.0633 - val_acc: 0.9820
# Epoch 393/1536
# ...
# Epoch 1407/1536
# Epoch 01406: val_loss did not improve
# 0s - loss: 1.3704 - acc: 0.8586 - val_loss: 0.0819 - val_acc: 0.9815
# Epoch 1408/1536
# Epoch 01407: val_loss did not improve
# 0s - loss: 0.0188 - acc: 0.9939 - val_loss: 0.0710 - val_acc: 0.9841
# Epoch 1409/1536
# Epoch 01408: val_loss did not improve
# 0s - loss: 0.0164 - acc: 0.9947 - val_loss: 0.0655 - val_acc: 0.9851
# Epoch 1410/1536
# Epoch 01409: val_loss did not improve
# 0s - loss: 0.0122 - acc: 0.9961 - val_loss: 0.0681 - val_acc: 0.9841
# Epoch 1411/1536
# Epoch 01410: val_loss did not improve
# 0s - loss: 0.0125 - acc: 0.9956 - val_loss: 0.0637 - val_acc: 0.9855
# Epoch 1412/1536
# Epoch 01411: val_loss did not improve
# 0s - loss: 0.0106 - acc: 0.9969 - val_loss: 0.0661 - val_acc: 0.9845
# Epoch 1413/1536
# Epoch 01412: val_loss did not improve
# 0s - loss: 0.0114 - acc: 0.9962 - val_loss: 0.0665 - val_acc: 0.9855
# Epoch 1414/1536
# Epoch 01413: val_loss did not improve
# 0s - loss: 0.0082 - acc: 0.9973 - val_loss: 0.0760 - val_acc: 0.9840
# Epoch 1415/1536
# Epoch 01414: val_loss did not improve
# 0s - loss: 0.3120 - acc: 0.9595 - val_loss: 0.8999 - val_acc: 0.8724
# Epoch 1416/1536
# Epoch 01415: val_loss did not improve
# 0s - loss: 0.4055 - acc: 0.9386 - val_loss: 0.0772 - val_acc: 0.9830
# Epoch 1417/1536
# Epoch 01416: val_loss did not improve
# 0s - loss: 0.0115 - acc: 0.9961 - val_loss: 0.0673 - val_acc: 0.9841
# Epoch 1418/1536
# Epoch 01417: val_loss did not improve
# 0s - loss: 0.0095 - acc: 0.9968 - val_loss: 0.0698 - val_acc: 0.9835
# Epoch 1419/1536
# Epoch 01418: val_loss did not improve
# 0s - loss: 0.0099 - acc: 0.9968 - val_loss: 0.0669 - val_acc: 0.9839
# Epoch 1420/1536
# Epoch 01419: val_loss did not improve
# 0s - loss: 0.0077 - acc: 0.9973 - val_loss: 0.0716 - val_acc: 0.9831
# Epoch 1421/1536
# Epoch 01420: val_loss did not improve
# 0s - loss: 0.7636 - acc: 0.9177 - val_loss: 1.7403 - val_acc: 0.8123
# Epoch 1422/1536
# Epoch 01421: val_loss did not improve
# 0s - loss: 0.5274 - acc: 0.9331 - val_loss: 0.0674 - val_acc: 0.9842
# Epoch 1423/1536
# Epoch 01422: val_loss did not improve
# 0s - loss: 0.0125 - acc: 0.9957 - val_loss: 0.0644 - val_acc: 0.9850
# Epoch 1424/1536
# Epoch 01423: val_loss did not improve
# 0s - loss: 0.0092 - acc: 0.9968 - val_loss: 0.0645 - val_acc: 0.9849
# Epoch 1425/1536
# Epoch 01424: val_loss did not improve
# 0s - loss: 0.0111 - acc: 0.9964 - val_loss: 0.0628 - val_acc: 0.9858
# Epoch 1426/1536
# Epoch 01425: val_loss did not improve
# 0s - loss: 0.0082 - acc: 0.9974 - val_loss: 0.0779 - val_acc: 0.9841
# Epoch 1427/1536
# Epoch 01426: val_loss did not improve
# 0s - loss: 0.0097 - acc: 0.9965 - val_loss: 0.0649 - val_acc: 0.9854
# Epoch 1428/1536
# Epoch 01427: val_loss did not improve
# 0s - loss: 0.0083 - acc: 0.9973 - val_loss: 0.1094 - val_acc: 0.9762
# Epoch 1429/1536
# Epoch 01428: val_loss did not improve
# 0s - loss: 0.6532 - acc: 0.9149 - val_loss: 0.2659 - val_acc: 0.9516
# Epoch 1430/1536
# Epoch 01429: val_loss did not improve
# 0s - loss: 0.0588 - acc: 0.9860 - val_loss: 0.0725 - val_acc: 0.9840
# Epoch 1431/1536
# Epoch 01430: val_loss did not improve
# 0s - loss: 0.0103 - acc: 0.9965 - val_loss: 0.0699 - val_acc: 0.9850
# Epoch 1432/1536
# Epoch 01431: val_loss did not improve
# 0s - loss: 0.0091 - acc: 0.9968 - val_loss: 0.0719 - val_acc: 0.9846
# Epoch 1433/1536
# Epoch 01432: val_loss did not improve
# 0s - loss: 0.0090 - acc: 0.9969 - val_loss: 0.0740 - val_acc: 0.9845
# Epoch 1434/1536
# Epoch 01433: val_loss did not improve
# 0s - loss: 0.0092 - acc: 0.9968 - val_loss: 0.0671 - val_acc: 0.9836
# Epoch 1435/1536
# Epoch 01434: val_loss did not improve
# 0s - loss: 0.0081 - acc: 0.9972 - val_loss: 0.0615 - val_acc: 0.9854
# Epoch 1436/1536
# Epoch 01435: val_loss did not improve
# 0s - loss: 0.1079 - acc: 0.9826 - val_loss: 1.9143 - val_acc: 0.8090
# Epoch 1437/1536
# Epoch 01436: val_loss did not improve
# 0s - loss: 0.8534 - acc: 0.8968 - val_loss: 0.0817 - val_acc: 0.9816
# Epoch 1438/1536
# Epoch 01437: val_loss did not improve
# 0s - loss: 0.0180 - acc: 0.9937 - val_loss: 0.0774 - val_acc: 0.9828
# Epoch 1439/1536
# Epoch 01438: val_loss did not improve
# 0s - loss: 0.0128 - acc: 0.9958 - val_loss: 0.0782 - val_acc: 0.9829
# Epoch 1440/1536
# Epoch 01439: val_loss did not improve
# 0s - loss: 0.0114 - acc: 0.9963 - val_loss: 0.0698 - val_acc: 0.9845
# Epoch 1441/1536
# Epoch 01440: val_loss did not improve
# 0s - loss: 0.0080 - acc: 0.9974 - val_loss: 0.0707 - val_acc: 0.9853
# Epoch 1442/1536
# Epoch 01441: val_loss did not improve
# 0s - loss: 0.1142 - acc: 0.9806 - val_loss: 0.6471 - val_acc: 0.8999
# Epoch 1443/1536
# Epoch 01442: val_loss did not improve
# 0s - loss: 0.3950 - acc: 0.9385 - val_loss: 0.0651 - val_acc: 0.9843
# Epoch 1444/1536
# Epoch 01443: val_loss did not improve
# 0s - loss: 0.0100 - acc: 0.9966 - val_loss: 0.0660 - val_acc: 0.9850
# Epoch 1445/1536
# Epoch 01444: val_loss did not improve
# 0s - loss: 0.0090 - acc: 0.9967 - val_loss: 0.0730 - val_acc: 0.9823
# Epoch 1446/1536
# Epoch 01445: val_loss did not improve
# 0s - loss: 0.0109 - acc: 0.9965 - val_loss: 0.0610 - val_acc: 0.9856
# Epoch 1447/1536
# Epoch 01446: val_loss did not improve
# 0s - loss: 0.0146 - acc: 0.9951 - val_loss: 0.0905 - val_acc: 0.9785
# Epoch 1448/1536
# Epoch 01447: val_loss did not improve
# 0s - loss: 0.4085 - acc: 0.9407 - val_loss: 0.9344 - val_acc: 0.8832
# Epoch 1449/1536
# Epoch 01448: val_loss did not improve
# 0s - loss: 0.6126 - acc: 0.9181 - val_loss: 0.0681 - val_acc: 0.9856
# Epoch 1450/1536
# Epoch 01449: val_loss did not improve
# 0s - loss: 0.0101 - acc: 0.9967 - val_loss: 0.0637 - val_acc: 0.9857
# Epoch 1451/1536
# Epoch 01450: val_loss did not improve
# 0s - loss: 0.0096 - acc: 0.9967 - val_loss: 0.0652 - val_acc: 0.9856
# Epoch 1452/1536
# Epoch 01451: val_loss did not improve
# 0s - loss: 0.0085 - acc: 0.9971 - val_loss: 0.0615 - val_acc: 0.9864
# Epoch 1453/1536
# Epoch 01452: val_loss did not improve
# 0s - loss: 0.0074 - acc: 0.9975 - val_loss: 0.0645 - val_acc: 0.9856
# Epoch 1454/1536
# Epoch 01453: val_loss did not improve
# 0s - loss: 0.0079 - acc: 0.9974 - val_loss: 0.0599 - val_acc: 0.9863
# Epoch 1455/1536
# Epoch 01454: val_loss did not improve
# 0s - loss: 0.0082 - acc: 0.9973 - val_loss: 0.0856 - val_acc: 0.9820
# Epoch 1456/1536
# Epoch 01455: val_loss did not improve
# 0s - loss: 0.4660 - acc: 0.9379 - val_loss: 1.5270 - val_acc: 0.8306
# Epoch 1457/1536
# Epoch 01456: val_loss did not improve
# 0s - loss: 0.6375 - acc: 0.9223 - val_loss: 0.0674 - val_acc: 0.9850
# Epoch 1458/1536
# Epoch 01457: val_loss did not improve
# 0s - loss: 0.0146 - acc: 0.9953 - val_loss: 0.0637 - val_acc: 0.9853
# Epoch 1459/1536
# Epoch 01458: val_loss did not improve
# 0s - loss: 0.0120 - acc: 0.9962 - val_loss: 0.0658 - val_acc: 0.9847
# Epoch 1460/1536
# Epoch 01459: val_loss did not improve
# 0s - loss: 0.0091 - acc: 0.9969 - val_loss: 0.0612 - val_acc: 0.9865
# Epoch 1461/1536
# Epoch 01460: val_loss did not improve
# 0s - loss: 0.0098 - acc: 0.9966 - val_loss: 0.0570 - val_acc: 0.9861
# Epoch 1462/1536
# Epoch 01461: val_loss did not improve
# 0s - loss: 0.0085 - acc: 0.9971 - val_loss: 0.0589 - val_acc: 0.9855
# Epoch 1463/1536
# Epoch 01462: val_loss did not improve
# 0s - loss: 0.0081 - acc: 0.9974 - val_loss: 0.0916 - val_acc: 0.9795
# Epoch 1464/1536
# Epoch 01463: val_loss did not improve
# 0s - loss: 1.1476 - acc: 0.8769 - val_loss: 0.2993 - val_acc: 0.9455
# Epoch 1465/1536
# Epoch 01464: val_loss did not improve
# 0s - loss: 0.0685 - acc: 0.9840 - val_loss: 0.0681 - val_acc: 0.9846
# Epoch 1466/1536
# Epoch 01465: val_loss did not improve
# 0s - loss: 0.0107 - acc: 0.9962 - val_loss: 0.0690 - val_acc: 0.9836
# Epoch 1467/1536
# Epoch 01466: val_loss did not improve
# 0s - loss: 0.0111 - acc: 0.9961 - val_loss: 0.0704 - val_acc: 0.9825
# Epoch 1468/1536
# Epoch 01467: val_loss did not improve
# 0s - loss: 0.0105 - acc: 0.9963 - val_loss: 0.0643 - val_acc: 0.9843
# Epoch 1469/1536
# Epoch 01468: val_loss did not improve
# 0s - loss: 0.0086 - acc: 0.9971 - val_loss: 0.0622 - val_acc: 0.9840
# Epoch 1470/1536
# Epoch 01469: val_loss did not improve
# 0s - loss: 0.0090 - acc: 0.9967 - val_loss: 0.0894 - val_acc: 0.9787
# Epoch 1471/1536
# Epoch 01470: val_loss did not improve
# 0s - loss: 0.5412 - acc: 0.9288 - val_loss: 0.6021 - val_acc: 0.9105
# Epoch 1472/1536
# Epoch 01471: val_loss did not improve
# 0s - loss: 0.2683 - acc: 0.9600 - val_loss: 0.0694 - val_acc: 0.9832
# Epoch 1473/1536
# Epoch 01472: val_loss did not improve
# 0s - loss: 0.0108 - acc: 0.9960 - val_loss: 0.0640 - val_acc: 0.9846
# Epoch 1474/1536
# Epoch 01473: val_loss did not improve
# 0s - loss: 0.0094 - acc: 0.9970 - val_loss: 0.0633 - val_acc: 0.9838
# Epoch 1475/1536
# Epoch 01474: val_loss did not improve
# 0s - loss: 0.0078 - acc: 0.9973 - val_loss: 0.0718 - val_acc: 0.9831
# Epoch 1476/1536
# Epoch 01475: val_loss did not improve
# 0s - loss: 0.1219 - acc: 0.9839 - val_loss: 0.1783 - val_acc: 0.9639
# Epoch 1477/1536
# Epoch 01476: val_loss did not improve
# 0s - loss: 0.2795 - acc: 0.9494 - val_loss: 0.0753 - val_acc: 0.9812
# Epoch 1478/1536
# Epoch 01477: val_loss did not improve
# 0s - loss: 0.0098 - acc: 0.9969 - val_loss: 0.0591 - val_acc: 0.9848
# Epoch 1479/1536
# Epoch 01478: val_loss did not improve
# 0s - loss: 0.0066 - acc: 0.9979 - val_loss: 0.0646 - val_acc: 0.9838
# Epoch 1480/1536
# Epoch 01479: val_loss did not improve
# 0s - loss: 0.0087 - acc: 0.9970 - val_loss: 0.0615 - val_acc: 0.9858
# Epoch 1481/1536
# Epoch 01480: val_loss did not improve
# 0s - loss: 0.0080 - acc: 0.9972 - val_loss: 0.0784 - val_acc: 0.9813
# Epoch 1482/1536
# Epoch 01481: val_loss did not improve
# 0s - loss: 0.4621 - acc: 0.9413 - val_loss: 0.6527 - val_acc: 0.8977
# Epoch 1483/1536
# Epoch 01482: val_loss did not improve
# 0s - loss: 0.4940 - acc: 0.9231 - val_loss: 0.0696 - val_acc: 0.9837
# Epoch 1484/1536
# Epoch 01483: val_loss did not improve
# 0s - loss: 0.0124 - acc: 0.9960 - val_loss: 0.0600 - val_acc: 0.9855
# Epoch 1485/1536
# Epoch 01484: val_loss did not improve
# 0s - loss: 0.0091 - acc: 0.9969 - val_loss: 0.0603 - val_acc: 0.9851
# Epoch 1486/1536
# Epoch 01485: val_loss did not improve
# 0s - loss: 0.0079 - acc: 0.9973 - val_loss: 0.0625 - val_acc: 0.9855
# Epoch 1487/1536
# Epoch 01486: val_loss did not improve
# 0s - loss: 0.0074 - acc: 0.9975 - val_loss: 0.0573 - val_acc: 0.9854
# Epoch 1488/1536
# Epoch 01487: val_loss did not improve
# 0s - loss: 0.0071 - acc: 0.9977 - val_loss: 0.0628 - val_acc: 0.9843
# Epoch 1489/1536
# Epoch 01488: val_loss did not improve
# 0s - loss: 0.3224 - acc: 0.9599 - val_loss: 1.1946 - val_acc: 0.8576
# Epoch 1490/1536
# Epoch 01489: val_loss did not improve
# 0s - loss: 0.4554 - acc: 0.9322 - val_loss: 0.0663 - val_acc: 0.9845
# Epoch 1491/1536
# Epoch 01490: val_loss did not improve
# 0s - loss: 0.0097 - acc: 0.9969 - val_loss: 0.0642 - val_acc: 0.9851
# Epoch 1492/1536
# Epoch 01491: val_loss did not improve
# 0s - loss: 0.0089 - acc: 0.9972 - val_loss: 0.0687 - val_acc: 0.9846
# Epoch 1493/1536
# Epoch 01492: val_loss did not improve
# 0s - loss: 0.0091 - acc: 0.9971 - val_loss: 0.0597 - val_acc: 0.9852
# Epoch 1494/1536
# Epoch 01493: val_loss did not improve
# 0s - loss: 0.0063 - acc: 0.9981 - val_loss: 0.0585 - val_acc: 0.9852
# Epoch 1495/1536
# Epoch 01494: val_loss did not improve
# 0s - loss: 0.0064 - acc: 0.9978 - val_loss: 0.0587 - val_acc: 0.9850
# Epoch 1496/1536
# Epoch 01495: val_loss did not improve
# 0s - loss: 0.0070 - acc: 0.9975 - val_loss: 0.0788 - val_acc: 0.9819
# Epoch 1497/1536
# Epoch 01496: val_loss did not improve
# 0s - loss: 0.6041 - acc: 0.9321 - val_loss: 0.5933 - val_acc: 0.9150
# Epoch 1498/1536
# Epoch 01497: val_loss did not improve
# 0s - loss: 0.2334 - acc: 0.9586 - val_loss: 0.0608 - val_acc: 0.9847
# Epoch 1499/1536
# Epoch 01498: val_loss did not improve
# 0s - loss: 0.0109 - acc: 0.9963 - val_loss: 0.0654 - val_acc: 0.9833
# Epoch 1500/1536
# Epoch 01499: val_loss did not improve
# 0s - loss: 0.0099 - acc: 0.9967 - val_loss: 0.0555 - val_acc: 0.9856
# Epoch 1501/1536
# Epoch 01500: val_loss did not improve
# 0s - loss: 0.0080 - acc: 0.9971 - val_loss: 0.0674 - val_acc: 0.9836
# Epoch 1502/1536
# Epoch 01501: val_loss did not improve
# 0s - loss: 0.0101 - acc: 0.9967 - val_loss: 0.0556 - val_acc: 0.9860
# Epoch 1503/1536
# Epoch 01502: val_loss did not improve
# 0s - loss: 0.0077 - acc: 0.9974 - val_loss: 0.0754 - val_acc: 0.9811
# Epoch 1504/1536
# Epoch 01503: val_loss did not improve
# 0s - loss: 0.2966 - acc: 0.9520 - val_loss: 1.3840 - val_acc: 0.8382
# Epoch 1505/1536
# Epoch 01504: val_loss did not improve
# 0s - loss: 0.8900 - acc: 0.8869 - val_loss: 0.0652 - val_acc: 0.9841
# Epoch 1506/1536
# Epoch 01505: val_loss did not improve
# 0s - loss: 0.0138 - acc: 0.9952 - val_loss: 0.0596 - val_acc: 0.9858
# Epoch 1507/1536
# Epoch 01506: val_loss did not improve
# 0s - loss: 0.0104 - acc: 0.9967 - val_loss: 0.0565 - val_acc: 0.9862
# Epoch 1508/1536
# Epoch 01507: val_loss did not improve
# 0s - loss: 0.0100 - acc: 0.9968 - val_loss: 0.0559 - val_acc: 0.9862
# Epoch 1509/1536
# Epoch 01508: val_loss did not improve
# 0s - loss: 0.0101 - acc: 0.9969 - val_loss: 0.0557 - val_acc: 0.9861
# Epoch 1510/1536
# Epoch 01509: val_loss did not improve
# 0s - loss: 0.0082 - acc: 0.9970 - val_loss: 0.0529 - val_acc: 0.9871
# Epoch 1511/1536
# Epoch 01510: val_loss did not improve
# 0s - loss: 0.0070 - acc: 0.9974 - val_loss: 0.0736 - val_acc: 0.9821
# Epoch 1512/1536
# Epoch 01511: val_loss did not improve
# 0s - loss: 0.6874 - acc: 0.9188 - val_loss: 0.5794 - val_acc: 0.9105
# Epoch 1513/1536
# Epoch 01512: val_loss did not improve
# 0s - loss: 0.1288 - acc: 0.9758 - val_loss: 0.0607 - val_acc: 0.9851
# Epoch 1514/1536
# Epoch 01513: val_loss did not improve
# 0s - loss: 0.0124 - acc: 0.9961 - val_loss: 0.0582 - val_acc: 0.9861
# Epoch 1515/1536
# Epoch 01514: val_loss did not improve
# 0s - loss: 0.0108 - acc: 0.9967 - val_loss: 0.0581 - val_acc: 0.9862
# Epoch 1516/1536
# Epoch 01515: val_loss did not improve
# 0s - loss: 0.0084 - acc: 0.9970 - val_loss: 0.0575 - val_acc: 0.9858
# Epoch 1517/1536
# Epoch 01516: val_loss did not improve
# 0s - loss: 0.0085 - acc: 0.9973 - val_loss: 0.0578 - val_acc: 0.9855
# Epoch 1518/1536
# Epoch 01517: val_loss did not improve
# 0s - loss: 0.0095 - acc: 0.9968 - val_loss: 0.0702 - val_acc: 0.9839
# Epoch 1519/1536
# Epoch 01518: val_loss did not improve
# 0s - loss: 0.4847 - acc: 0.9393 - val_loss: 0.7632 - val_acc: 0.8908
# Epoch 1520/1536
# Epoch 01519: val_loss did not improve
# 0s - loss: 0.2378 - acc: 0.9605 - val_loss: 0.0647 - val_acc: 0.9845
# Epoch 1521/1536
# Epoch 01520: val_loss did not improve
# 0s - loss: 0.0103 - acc: 0.9967 - val_loss: 0.0603 - val_acc: 0.9844
# Epoch 1522/1536
# Epoch 01521: val_loss did not improve
# 0s - loss: 0.0082 - acc: 0.9968 - val_loss: 0.0648 - val_acc: 0.9838
# Epoch 1523/1536
# Epoch 01522: val_loss did not improve
# 0s - loss: 0.0072 - acc: 0.9975 - val_loss: 0.0581 - val_acc: 0.9856
# Epoch 1524/1536
# Epoch 01523: val_loss did not improve
# 0s - loss: 0.0060 - acc: 0.9980 - val_loss: 0.0843 - val_acc: 0.9816
# Epoch 1525/1536
# Epoch 01524: val_loss did not improve
# 0s - loss: 0.2263 - acc: 0.9612 - val_loss: 0.7293 - val_acc: 0.8947
# Epoch 1526/1536
# Epoch 01525: val_loss did not improve
# 0s - loss: 0.4774 - acc: 0.9293 - val_loss: 0.0654 - val_acc: 0.9838
# Epoch 1527/1536
# Epoch 01526: val_loss did not improve
# 0s - loss: 0.0088 - acc: 0.9969 - val_loss: 0.0611 - val_acc: 0.9842
# Epoch 1528/1536
# Epoch 01527: val_loss did not improve
# 0s - loss: 0.0073 - acc: 0.9978 - val_loss: 0.0607 - val_acc: 0.9845
# Epoch 1529/1536
# Epoch 01528: val_loss did not improve
# 0s - loss: 0.0071 - acc: 0.9976 - val_loss: 0.0588 - val_acc: 0.9853
# Epoch 1530/1536
# Epoch 01529: val_loss did not improve
# 0s - loss: 0.0072 - acc: 0.9976 - val_loss: 0.0570 - val_acc: 0.9858
# Epoch 1531/1536
# Epoch 01530: val_loss did not improve
# 0s - loss: 0.0051 - acc: 0.9983 - val_loss: 0.0678 - val_acc: 0.9840
# Epoch 1532/1536
# Epoch 01531: val_loss did not improve
# 0s - loss: 0.4678 - acc: 0.9418 - val_loss: 0.8597 - val_acc: 0.8720
# Epoch 1533/1536
# Epoch 01532: val_loss did not improve
# 0s - loss: 0.4288 - acc: 0.9330 - val_loss: 0.0654 - val_acc: 0.9823
# Epoch 1534/1536
# Epoch 01533: val_loss did not improve
# 0s - loss: 0.0115 - acc: 0.9961 - val_loss: 0.0599 - val_acc: 0.9847
# Epoch 1535/1536
# Epoch 01534: val_loss did not improve
# 0s - loss: 0.0095 - acc: 0.9972 - val_loss: 0.0570 - val_acc: 0.9856
# Epoch 1536/1536
# Epoch 01535: val_loss did not improve
# 0s - loss: 0.0075 - acc: 0.9974 - val_loss: 0.0597 - val_acc: 0.9842

# %% [markdown]
# ### Evaluating the model

# %%
# Load the weights that yielded the best validation accuracy
model.load_weights(model_weights_path)

# Evaluate test accuracy
score = model.evaluate(features_test, test_targets, verbose=0)
accuracy = 100*score[1]

# Print test accuracy
print('Test accuracy: %.4f%%' % accuracy)
# Out:
# Test accuracy: 69.7152%

# %% [markdown]
# ## Confusion Matrix of Test Data
#
# After performing tests, a confusion matrix can be used to evaluate the model and it's accuracy for each ASL handshape/letter. Below we use the weight's from the last model defined and used above to generate our confusion matrix.

# %%
# Load the weights of latest model run
model.load_weights(model_weights_path)

test_predictions = model.predict_classes(features_test)
# Out:
# 12768/12782 [============================>.] - ETA: 0s

# %%
sess = tf.Session()
# Change one-hot encoding to just an integer representing letter
un_hot_encode_targets = np.argmax(test_targets, axis=1)

confusion_arr = sess.run(tf.confusion_matrix(un_hot_encode_targets, test_predictions, 24))
# Get percents to compare with research paper benchmark
confusion_arr_percents = confusion_arr/sum(confusion_arr)

# %%
# Note no 'J' & 'Z' were used
letters = "ABCDEFGHIKLMNOPQRSTUVWXY"

# Print out counts to see distribution of the number of letters tested against
for elem in ['{}: {}'.format(letter,count) for letter,count in zip(letters,sum(confusion_arr))]:
    print(elem)
# Out:
# A: 705
# B: 586
# C: 519
# D: 461
# E: 764
# F: 450
# G: 766
# H: 185
# I: 450
# K: 494
# L: 469
# M: 453
# N: 1239
# O: 380
# P: 526
# Q: 285
# R: 681
# S: 513
# T: 225
# U: 671
# V: 725
# W: 519
# X: 224
# Y: 492

# %%
# Save confusion matrix/array as CSVs for reference
np.savetxt('confusion_matrices/confusionMatrix_{}_counts.csv'.format(model_details),confusion_arr)
np.savetxt('confusion_matrices/confusionMatrix_{}_percent.csv'.format(model_details),confusion_arr_percents)

# %%
df_cm = pd.DataFrame(confusion_arr, index = [i for i in letters],
                  columns = [i for i in letters])
plt.figure(figsize = (25,20))
sn.heatmap(df_cm, annot=True)

# %%
# Percentages for confusion matrix
# Multiplied by 100 to make it easier to read values
df_cm = pd.DataFrame(confusion_arr_percents*100, index = [i for i in letters],
                  columns = [i for i in letters])
plt.figure(figsize = (15,10))
sn.heatmap(df_cm, annot=True)
